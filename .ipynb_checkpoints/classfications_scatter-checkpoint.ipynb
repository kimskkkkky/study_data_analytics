# %%
class1_x_value = [0, 1, 2, 3, 4]
class1_y_value = [1, 3, 5, 7, 9]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=class1_x_value, y=class1_y_value)

# %%
class2_x_value = [1.5, 2.5, 3.5, 4.5, 5.5]
class2_y_value = [3.5, 5.5, 7.5, 9.5, 11.5]

# %%
plt.scatter(x=class2_x_value, y=class2_y_value)

# %% [markdown]
# ### title, label, legend(제목, 레이블, 범례)

# %%
# 두 class 변수를 한 plot에 표현
plt.scatter(x=class1_x_value, y=class1_y_value, label = 'class one')
plt.scatter(x=class2_x_value, y=class2_y_value, label = 'class two')
plt.title('Classfications Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.show()

# %%
class3_x_value = [2, 3, 4, 0, 1]
class3_y_value = [5, 7, 9, 1, 3]
plt.scatter(x=class3_x_value, y=class3_y_value)

# %%
plt.plot(class3_x_value, class3_y_value)

# %%
class3_x_value = [2,3.5,0,5,1,8]
class3_y_value = [5,6,1,-1,0,3]
class3_x_value, len(class3_x_value), class3_y_value, len(class3_y_value)
plt.scatter(x=class3_x_value, y=class3_y_value)
