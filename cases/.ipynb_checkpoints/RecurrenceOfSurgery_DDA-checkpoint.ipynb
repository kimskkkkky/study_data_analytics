# %%
import pymongo as mg
import pandas as pd

# %%
df_ROS = pd.read_csv('../../../../datasets/RecurrenceOfSurgery.csv')
df_ROS.head()
# Out:
#    Unnamed: 0 환자ID  Large Lymphocyte  Location of herniation   ODI  가족력  \
# 0           0  1PT              22.8                       3  51.0  0.0
# 1           1  2PT              44.9                       4  26.0  0.0
# 2           2  3PT              53.0                       3   NaN  0.0
# 3           3  4PT              54.7                       4  18.0  0.0
# 4           4  5PT              53.8                       4   NaN  0.0
#
#    간질성폐질환  고혈압여부  과거수술횟수  당뇨여부  ...  Modic change    PI    PT  Seg Angle(raw)  \
# 0       0      0       0     0  ...             3  51.6  36.6            14.4
# 1       0      0       0     0  ...             0  40.8   7.2            17.8
# 2       0      0       1     0  ...             0  67.5  27.3            10.2
# 3       0      1       0     0  ...             0  49.2  18.7            19.9
# 4       0      1       0     0  ...             0  58.8  14.7             5.2
#
#    Vaccum disc   골밀도   디스크단면적  디스크위치  척추이동척도  척추전방위증
# 0            0 -1.01  2048.50      4    Down       0
# 1            0 -1.14  1753.10      4      Up       0
# 2            0 -1.77  1749.00      4    Down       0
# 3            0 -1.58  1796.20      4    Down       0
# 4            0 -0.79  2021.48      4      Up       0
#
# [5 rows x 52 columns]

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_medicals']
database
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_medicals')

# %%
collection = database['RecurrenceOfSurgery']
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_medicals'), 'RecurrenceOfSurgery')

# %%
data_list = df_ROS.to_dict(orient = 'records')
data_list
# Out:
# [{'Unnamed: 0': 0,
#   '환자ID': '1PT',
#   'Large Lymphocyte': 22.8,
#   'Location of herniation': 3,
#   'ODI': 51.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 163,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 66,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190713,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 60.3,
#   '퇴원일자': 20190716,
#   '헤모글로빈수치': 13.66,
#   '혈전합병증여부': 0,
#   '환자통증정도': 10,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 68.0,
#   '수술실패여부': 0,
#   '수술일자': 20190715,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 16.1,
#   '후방디스크높이(mm)': 12.3,
#   '지방축적도': 282.3,
#   'Instability': 0,
#   'MF + ES': 1824.6,
#   'Modic change': 3,
#   'PI': 51.6,
#   'PT': 36.6,
#   'Seg Angle(raw)': 14.4,
#   'Vaccum disc': 0,
#   '골밀도': -1.01,
#   '디스크단면적': 2048.5,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 1,
#   '환자ID': '2PT',
#   'Large Lymphocyte': 44.9,
#   'Location of herniation': 4,
#   'ODI': 26.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 171,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 47,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190715,
#   '종양진행여부': 0,
#   '직업': '운동선수',
#   '체중': 71.7,
#   '퇴원일자': 20190716,
#   '헤모글로빈수치': 13.73,
#   '혈전합병증여부': 0,
#   '환자통증정도': 10,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 31.0,
#   '수술실패여부': 0,
#   '수술일자': 20190716,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 13.7,
#   '후방디스크높이(mm)': 6.4,
#   '지방축적도': 177.3,
#   'Instability': 0,
#   'MF + ES': 1737.5,
#   'Modic change': 0,
#   'PI': 40.8,
#   'PT': 7.2,
#   'Seg Angle(raw)': 17.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.14,
#   '디스크단면적': 1753.1,
#   '디스크위치': 4,
#   '척추이동척도': 'Up',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 2,
#   '환자ID': '3PT',
#   'Large Lymphocyte': 53.0,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 178,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 39,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190729,
#   '종양진행여부': 0,
#   '직업': '특수전문직',
#   '체중': 77.1,
#   '퇴원일자': 20190801,
#   '헤모글로빈수치': 15.34,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 78.0,
#   '수술실패여부': 0,
#   '수술일자': 20190731,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 13.6,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 256.8,
#   'Instability': 0,
#   'MF + ES': 1188.5,
#   'Modic change': 0,
#   'PI': 67.5,
#   'PT': 27.3,
#   'Seg Angle(raw)': 10.2,
#   'Vaccum disc': 0,
#   '골밀도': -1.77,
#   '디스크단면적': 1749.0,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 3,
#   '환자ID': '4PT',
#   'Large Lymphocyte': 54.7,
#   'Location of herniation': 4,
#   'ODI': 18.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 174,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 40,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190731,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 74.2,
#   '퇴원일자': 20190803,
#   '헤모글로빈수치': 15.38,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 73.0,
#   '수술실패여부': 0,
#   '수술일자': 20190802,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 10.6,
#   '후방디스크높이(mm)': 7.3,
#   '지방축적도': 250.1,
#   'Instability': 0,
#   'MF + ES': 2534.5,
#   'Modic change': 0,
#   'PI': 49.2,
#   'PT': 18.7,
#   'Seg Angle(raw)': 19.9,
#   'Vaccum disc': 0,
#   '골밀도': -1.58,
#   '디스크단면적': 1796.2,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 4,
#   '환자ID': '5PT',
#   'Large Lymphocyte': 53.8,
#   'Location of herniation': 4,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 183,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 42,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190903,
#   '종양진행여부': 0,
#   '직업': '특수전문직',
#   '체중': 80.7,
#   '퇴원일자': 20190907,
#   '헤모글로빈수치': 13.08,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 29.0,
#   '수술실패여부': 0,
#   '수술일자': 20190906,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 17.1,
#   '후방디스크높이(mm)': 8.1,
#   '지방축적도': 232.2,
#   'Instability': 0,
#   'MF + ES': 1840.6,
#   'Modic change': 0,
#   'PI': 58.8,
#   'PT': 14.7,
#   'Seg Angle(raw)': 5.2,
#   'Vaccum disc': 0,
#   '골밀도': -0.79,
#   '디스크단면적': 2021.48,
#   '디스크위치': 4,
#   '척추이동척도': 'Up',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 5,
#   '환자ID': '6PT',
#   'Large Lymphocyte': 28.5,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 1,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 164,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 60,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190905,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 60.8,
#   '퇴원일자': 20190907,
#   '헤모글로빈수치': 15.2,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 47.0,
#   '수술실패여부': 0,
#   '수술일자': 20190907,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 12.8,
#   '후방디스크높이(mm)': 10.7,
#   '지방축적도': 129.9,
#   'Instability': 0,
#   'MF + ES': 1683.6,
#   'Modic change': 0,
#   'PI': 41.8,
#   'PT': 23.6,
#   'Seg Angle(raw)': 8.8,
#   'Vaccum disc': 0,
#   '골밀도': -0.95,
#   '디스크단면적': 1937.5,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 6,
#   '환자ID': '7PT',
#   'Large Lymphocyte': 4.2,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 1,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 175,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 47,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190622,
#   '종양진행여부': 0,
#   '직업': '사업가',
#   '체중': 74.8,
#   '퇴원일자': 20190626,
#   '헤모글로빈수치': 15.78,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 7.0,
#   '수술실패여부': 0,
#   '수술일자': 20190625,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 12.2,
#   '후방디스크높이(mm)': 8.4,
#   '지방축적도': 177.3,
#   'Instability': 0,
#   'MF + ES': 1979.6,
#   'Modic change': 0,
#   'PI': 41.9,
#   'PT': 17.4,
#   'Seg Angle(raw)': 1.53,
#   'Vaccum disc': 1,
#   '골밀도': -1.71,
#   '디스크단면적': 2466.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 7,
#   '환자ID': '8PT',
#   'Large Lymphocyte': 43.8,
#   'Location of herniation': 4,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 183,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 55,
#   '우울증여부': 1,
#   '입원기간': 1,
#   '입원일자': 20190330,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 81.2,
#   '퇴원일자': 20190402,
#   '헤모글로빈수치': 15.35,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 85.0,
#   '수술실패여부': 0,
#   '수술일자': 20190402,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 14.1,
#   '후방디스크높이(mm)': 8.6,
#   '지방축적도': 161.02,
#   'Instability': 0,
#   'MF + ES': 1789.6,
#   'Modic change': 0,
#   'PI': 50.6,
#   'PT': 18.5,
#   'Seg Angle(raw)': 10.7,
#   'Vaccum disc': 0,
#   '골밀도': -1.04,
#   '디스크단면적': 1830.58,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 8,
#   '환자ID': '9PT',
#   'Large Lymphocyte': 89.0,
#   'Location of herniation': 3,
#   'ODI': 31.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 168,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 52,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191203,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 69.2,
#   '퇴원일자': 20191206,
#   '헤모글로빈수치': 15.03,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 49.0,
#   '수술실패여부': 0,
#   '수술일자': 20191206,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 14.7,
#   '후방디스크높이(mm)': 7.5,
#   '지방축적도': 157.21,
#   'Instability': 0,
#   'MF + ES': 1375.5,
#   'Modic change': 0,
#   'PI': 48.8,
#   'PT': 13.6,
#   'Seg Angle(raw)': 13.8,
#   'Vaccum disc': 1,
#   '골밀도': -1.33,
#   '디스크단면적': 2021.75,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 9,
#   '환자ID': '10PT',
#   'Large Lymphocyte': 40.5,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 160,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 79,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20191210,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 63.0,
#   '퇴원일자': 20191213,
#   '헤모글로빈수치': 14.74,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 59.0,
#   '수술실패여부': 1,
#   '수술일자': 20191213,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 17.9,
#   '후방디스크높이(mm)': 9.6,
#   '지방축적도': 127.1,
#   'Instability': 0,
#   'MF + ES': 1601.9,
#   'Modic change': 0,
#   'PI': 38.9,
#   'PT': 14.7,
#   'Seg Angle(raw)': 14.2,
#   'Vaccum disc': 0,
#   '골밀도': -2.51,
#   '디스크단면적': 2302.5,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 10,
#   '환자ID': '11PT',
#   'Large Lymphocyte': 31.8,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 161,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 43,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191217,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 59.5,
#   '퇴원일자': 20191219,
#   '헤모글로빈수치': 12.04,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 49.0,
#   '수술실패여부': 0,
#   '수술일자': 20191219,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 11.9,
#   '후방디스크높이(mm)': 8.6,
#   '지방축적도': 211.7,
#   'Instability': 1,
#   'MF + ES': 1462.5,
#   'Modic change': 0,
#   'PI': 58.6,
#   'PT': 33.9,
#   'Seg Angle(raw)': 18.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.68,
#   '디스크단면적': 1678.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 11,
#   '환자ID': '12PT',
#   'Large Lymphocyte': 53.2,
#   'Location of herniation': 3,
#   'ODI': 39.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 162,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 65,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190206,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 64.9,
#   '퇴원일자': 20190209,
#   '헤모글로빈수치': 17.28,
#   '혈전합병증여부': 0,
#   '환자통증정도': 10,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 49.0,
#   '수술실패여부': 0,
#   '수술일자': 20190209,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 12.5,
#   '후방디스크높이(mm)': 6.8,
#   '지방축적도': 104.4,
#   'Instability': 0,
#   'MF + ES': 2636.91,
#   'Modic change': 2,
#   'PI': 37.2,
#   'PT': 8.9,
#   'Seg Angle(raw)': 13.5,
#   'Vaccum disc': 1,
#   '골밀도': -1.35,
#   '디스크단면적': 2119.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 12,
#   '환자ID': '13PT',
#   'Large Lymphocyte': 20.3,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 174,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 35,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20191120,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 74.4,
#   '퇴원일자': 20191121,
#   '헤모글로빈수치': 17.23,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 94.0,
#   '수술실패여부': 0,
#   '수술일자': 20191121,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 9.6,
#   '후방디스크높이(mm)': 7.3,
#   '지방축적도': 61.0,
#   'Instability': 1,
#   'MF + ES': 1967.7,
#   'Modic change': 2,
#   'PI': 42.9,
#   'PT': 21.3,
#   'Seg Angle(raw)': 9.1,
#   'Vaccum disc': 0,
#   '골밀도': -1.38,
#   '디스크단면적': 1915.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 13,
#   '환자ID': '14PT',
#   'Large Lymphocyte': 59.4,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 175,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 30,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191221,
#   '종양진행여부': 0,
#   '직업': '건설업',
#   '체중': 74.6,
#   '퇴원일자': 20191222,
#   '헤모글로빈수치': 14.93,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 13.0,
#   '수술실패여부': 0,
#   '수술일자': 20191222,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 14.3,
#   '후방디스크높이(mm)': 9.1,
#   '지방축적도': 499.8,
#   'Instability': 0,
#   'MF + ES': 1878.5,
#   'Modic change': 1,
#   'PI': 61.6,
#   'PT': 19.0,
#   'Seg Angle(raw)': 17.0,
#   'Vaccum disc': 0,
#   '골밀도': -1.74,
#   '디스크단면적': 1642.2,
#   '디스크위치': 5,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 14,
#   '환자ID': '15PT',
#   'Large Lymphocyte': 32.1,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 158,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 56,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190619,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 58.4,
#   '퇴원일자': 20190620,
#   '헤모글로빈수치': 14.1,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 96.0,
#   '수술실패여부': 0,
#   '수술일자': 20190620,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 14.4,
#   '후방디스크높이(mm)': 8.3,
#   '지방축적도': 252.8,
#   'Instability': 0,
#   'MF + ES': 2012.5,
#   'Modic change': 0,
#   'PI': 49.9,
#   'PT': 17.1,
#   'Seg Angle(raw)': 23.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.56,
#   '디스크단면적': 2268.5,
#   '디스크위치': 5,
#   '척추이동척도': 'Down',
#   '척추전방위증': 1},
#  {'Unnamed: 0': 15,
#   '환자ID': '16PT',
#   'Large Lymphocyte': 23.3,
#   'Location of herniation': 4,
#   'ODI': 22.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 176,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 84,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190220,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 75.6,
#   '퇴원일자': 20190222,
#   '헤모글로빈수치': 15.05,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 42.0,
#   '수술실패여부': 0,
#   '수술일자': 20190222,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 10.5,
#   '후방디스크높이(mm)': 5.41,
#   '지방축적도': 121.0,
#   'Instability': 0,
#   'MF + ES': 1199.0,
#   'Modic change': 2,
#   'PI': 40.2,
#   'PT': 14.1,
#   'Seg Angle(raw)': 13.8,
#   'Vaccum disc': 0,
#   '골밀도': -2.12,
#   '디스크단면적': 2155.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 16,
#   '환자ID': '17PT',
#   'Large Lymphocyte': 45.4,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 168,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 34,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190219,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 69.5,
#   '퇴원일자': 20190223,
#   '헤모글로빈수치': 15.33,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 3.0,
#   '수술기법': 'TELD',
#   '수술시간': 68.0,
#   '수술실패여부': 0,
#   '수술일자': 20190222,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 18.1,
#   '후방디스크높이(mm)': 9.6,
#   '지방축적도': 87.6,
#   'Instability': 0,
#   'MF + ES': 1746.3,
#   'Modic change': 0,
#   'PI': 38.8,
#   'PT': 12.7,
#   'Seg Angle(raw)': 14.7,
#   'Vaccum disc': 0,
#   '골밀도': -1.52,
#   '디스크단면적': 2408.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 17,
#   '환자ID': '18PT',
#   'Large Lymphocyte': 51.1,
#   'Location of herniation': 2,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 188,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 75,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190219,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 85.2,
#   '퇴원일자': 20190223,
#   '헤모글로빈수치': 16.49,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 46.0,
#   '수술실패여부': 0,
#   '수술일자': 20190222,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 14.0,
#   '후방디스크높이(mm)': 8.2,
#   '지방축적도': 253.1,
#   'Instability': 0,
#   'MF + ES': 1930.7,
#   'Modic change': 0,
#   'PI': 65.9,
#   'PT': 17.5,
#   'Seg Angle(raw)': 14.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.07,
#   '디스크단면적': 2079.0,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 18,
#   '환자ID': '19PT',
#   'Large Lymphocyte': 44.6,
#   'Location of herniation': 2,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 184,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 66,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190226,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 82.1,
#   '퇴원일자': 20190227,
#   '헤모글로빈수치': 14.94,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 71.0,
#   '수술실패여부': 0,
#   '수술일자': 20190227,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 19.6,
#   '후방디스크높이(mm)': 10.2,
#   '지방축적도': 184.6,
#   'Instability': 0,
#   'MF + ES': 2152.3,
#   'Modic change': 2,
#   'PI': 32.0,
#   'PT': 12.6,
#   'Seg Angle(raw)': 11.1,
#   'Vaccum disc': 0,
#   '골밀도': -0.77,
#   '디스크단면적': 1750.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 19,
#   '환자ID': '20PT',
#   'Large Lymphocyte': 39.2,
#   'Location of herniation': 3,
#   'ODI': 26.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 162,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 62,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190226,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 59.9,
#   '퇴원일자': 20190227,
#   '헤모글로빈수치': 15.67,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 2.0,
#   '수술기법': 'IELD',
#   '수술시간': 73.0,
#   '수술실패여부': 0,
#   '수술일자': 20190227,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 12.7,
#   '후방디스크높이(mm)': 7.8,
#   '지방축적도': 220.5,
#   'Instability': 0,
#   'MF + ES': 2101.3,
#   'Modic change': 0,
#   'PI': 37.1,
#   'PT': 11.9,
#   'Seg Angle(raw)': 11.9,
#   'Vaccum disc': 0,
#   '골밀도': -1.92,
#   '디스크단면적': 2056.6,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 20,
#   '환자ID': '21PT',
#   'Large Lymphocyte': 24.6,
#   'Location of herniation': 3,
#   'ODI': 10.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 166,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 56,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190106,
#   '종양진행여부': 0,
#   '직업': '운수업',
#   '체중': 68.3,
#   '퇴원일자': 20190108,
#   '헤모글로빈수치': 11.2,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 54.0,
#   '수술실패여부': 1,
#   '수술일자': 20190108,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 11.2,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 137.6,
#   'Instability': 0,
#   'MF + ES': 1576.6,
#   'Modic change': 2,
#   'PI': 49.0,
#   'PT': 31.4,
#   'Seg Angle(raw)': 2.6,
#   'Vaccum disc': 0,
#   '골밀도': -1.14,
#   '디스크단면적': 2299.1,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 21,
#   '환자ID': '22PT',
#   'Large Lymphocyte': 24.6,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 158,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 56,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20190129,
#   '종양진행여부': 0,
#   '직업': '운수업',
#   '체중': 58.6,
#   '퇴원일자': 20190201,
#   '헤모글로빈수치': 12.84,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 82.0,
#   '수술실패여부': 0,
#   '수술일자': 20190131,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 11.2,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 137.6,
#   'Instability': 0,
#   'MF + ES': 1576.6,
#   'Modic change': 2,
#   'PI': 49.0,
#   'PT': 31.4,
#   'Seg Angle(raw)': 2.6,
#   'Vaccum disc': 0,
#   '골밀도': -1.86,
#   '디스크단면적': 2299.1,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 22,
#   '환자ID': '23PT',
#   'Large Lymphocyte': 59.2,
#   'Location of herniation': 3,
#   'ODI': 30.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 154,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 74,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190225,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 57.2,
#   '퇴원일자': 20190301,
#   '헤모글로빈수치': 12.63,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 51.0,
#   '수술실패여부': 0,
#   '수술일자': 20190228,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 14.3,
#   '후방디스크높이(mm)': 8.0,
#   '지방축적도': 394.1,
#   'Instability': 0,
#   'MF + ES': 1724.5,
#   'Modic change': 2,
#   'PI': 61.0,
#   'PT': 16.4,
#   'Seg Angle(raw)': 23.2,
#   'Vaccum disc': 0,
#   '골밀도': -1.59,
#   '디스크단면적': 1744.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 23,
#   '환자ID': '24PT',
#   'Large Lymphocyte': 28.5,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 179,
#   '심혈관질환': 1,
#   '암발병여부': 0,
#   '연령': 42,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190330,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 77.8,
#   '퇴원일자': 20190331,
#   '헤모글로빈수치': 16.35,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 86.0,
#   '수술실패여부': 0,
#   '수술일자': 20190331,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 13.8,
#   '후방디스크높이(mm)': 8.7,
#   '지방축적도': 120.5,
#   'Instability': 1,
#   'MF + ES': 2688.8,
#   'Modic change': 0,
#   'PI': 41.8,
#   'PT': 20.8,
#   'Seg Angle(raw)': 10.3,
#   'Vaccum disc': 1,
#   '골밀도': -1.69,
#   '디스크단면적': 2205.2,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 24,
#   '환자ID': '25PT',
#   'Large Lymphocyte': 44.9,
#   'Location of herniation': 3,
#   'ODI': 29.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 168,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 35,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190623,
#   '종양진행여부': 0,
#   '직업': '사업가',
#   '체중': 69.8,
#   '퇴원일자': 20190625,
#   '헤모글로빈수치': 15.95,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 73.0,
#   '수술실패여부': 0,
#   '수술일자': 20190625,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 13.9,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 122.0,
#   'Instability': 1,
#   'MF + ES': 2183.9,
#   'Modic change': 0,
#   'PI': 43.7,
#   'PT': 13.1,
#   'Seg Angle(raw)': 22.6,
#   'Vaccum disc': 0,
#   '골밀도': -2.36,
#   '디스크단면적': 1802.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 25,
#   '환자ID': '26PT',
#   'Large Lymphocyte': 44.9,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 186,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 52,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191001,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 83.2,
#   '퇴원일자': 20191004,
#   '헤모글로빈수치': 14.31,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 106.0,
#   '수술실패여부': 0,
#   '수술일자': 20191003,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 12.4,
#   '후방디스크높이(mm)': 7.1,
#   '지방축적도': 122.0,
#   'Instability': 0,
#   'MF + ES': 2183.9,
#   'Modic change': 0,
#   'PI': 43.7,
#   'PT': 13.1,
#   'Seg Angle(raw)': 18.9,
#   'Vaccum disc': 0,
#   '골밀도': -1.58,
#   '디스크단면적': 1802.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 26,
#   '환자ID': '27PT',
#   'Large Lymphocyte': 42.8,
#   'Location of herniation': 4,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 184,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 63,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20191001,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 82.0,
#   '퇴원일자': 20191003,
#   '헤모글로빈수치': 16.52,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 89.0,
#   '수술실패여부': 0,
#   '수술일자': 20191003,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 13.2,
#   '후방디스크높이(mm)': 8.3,
#   '지방축적도': 161.6,
#   'Instability': 0,
#   'MF + ES': 2188.8,
#   'Modic change': 0,
#   'PI': 41.4,
#   'PT': 16.1,
#   'Seg Angle(raw)': 2.1,
#   'Vaccum disc': 0,
#   '골밀도': -1.23,
#   '디스크단면적': 2097.0,
#   '디스크위치': 5,
#   '척추이동척도': 'Up',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 27,
#   '환자ID': '28PT',
#   'Large Lymphocyte': 21.5,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 179,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 37,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191021,
#   '종양진행여부': 0,
#   '직업': '공무원',
#   '체중': 78.0,
#   '퇴원일자': 20191023,
#   '헤모글로빈수치': 15.11,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 58.0,
#   '수술실패여부': 0,
#   '수술일자': 20191022,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 11.3,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 163.8,
#   'Instability': 1,
#   'MF + ES': 1458.3,
#   'Modic change': 0,
#   'PI': 45.1,
#   'PT': 21.6,
#   'Seg Angle(raw)': 14.5,
#   'Vaccum disc': 0,
#   '골밀도': -1.26,
#   '디스크단면적': 1812.2,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 28,
#   '환자ID': '29PT',
#   'Large Lymphocyte': 30.2,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 179,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 64,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191215,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 77.8,
#   '퇴원일자': 20191218,
#   '헤모글로빈수치': 15.89,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 35.0,
#   '수술실패여부': 0,
#   '수술일자': 20191218,
#   '재발여부': 1,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 8.5,
#   '후방디스크높이(mm)': 7.5,
#   '지방축적도': 111.5,
#   'Instability': 0,
#   'MF + ES': 1510.7,
#   'Modic change': 2,
#   'PI': 52.9,
#   'PT': 25.0,
#   'Seg Angle(raw)': 15.9,
#   'Vaccum disc': 0,
#   '골밀도': -1.37,
#   '디스크단면적': 2035.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 29,
#   '환자ID': '30PT',
#   'Large Lymphocyte': 30.2,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 166,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 58,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191215,
#   '종양진행여부': 0,
#   '직업': '농업',
#   '체중': 68.2,
#   '퇴원일자': 20191218,
#   '헤모글로빈수치': 15.8,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 71.0,
#   '수술실패여부': 0,
#   '수술일자': 20191218,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 8.5,
#   '후방디스크높이(mm)': 7.5,
#   '지방축적도': 111.5,
#   'Instability': 0,
#   'MF + ES': 1510.7,
#   'Modic change': 2,
#   'PI': 52.9,
#   'PT': 25.0,
#   'Seg Angle(raw)': 15.9,
#   'Vaccum disc': 0,
#   '골밀도': -1.97,
#   '디스크단면적': 2035.9,
#   '디스크위치': 5,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 30,
#   '환자ID': '31PT',
#   'Large Lymphocyte': 51.1,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 1,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 173,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 52,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20191215,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 73.3,
#   '퇴원일자': 20191218,
#   '헤모글로빈수치': 14.22,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'IELD',
#   '수술시간': 58.0,
#   '수술실패여부': 0,
#   '수술일자': 20191218,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 17.2,
#   '후방디스크높이(mm)': 8.5,
#   '지방축적도': 229.2,
#   'Instability': 0,
#   'MF + ES': 2097.4,
#   'Modic change': 0,
#   'PI': 45.3,
#   'PT': 14.9,
#   'Seg Angle(raw)': 20.2,
#   'Vaccum disc': 0,
#   '골밀도': -1.64,
#   '디스크단면적': 1833.2,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 31,
#   '환자ID': '32PT',
#   'Large Lymphocyte': 51.4,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 173,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 30,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200102,
#   '종양진행여부': 0,
#   '직업': '건설업',
#   '체중': 73.4,
#   '퇴원일자': 20200105,
#   '헤모글로빈수치': 15.6,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 65.0,
#   '수술실패여부': 0,
#   '수술일자': 20200104,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 15.8,
#   '후방디스크높이(mm)': 8.4,
#   '지방축적도': 196.0,
#   'Instability': 0,
#   'MF + ES': 1959.3,
#   'Modic change': 0,
#   'PI': 51.2,
#   'PT': 18.7,
#   'Seg Angle(raw)': 13.9,
#   'Vaccum disc': 0,
#   '골밀도': -1.8,
#   '디스크단면적': 1659.0,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 32,
#   '환자ID': '33PT',
#   'Large Lymphocyte': 33.2,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 170,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 57,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200106,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 70.9,
#   '퇴원일자': 20200107,
#   '헤모글로빈수치': 15.19,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 72.0,
#   '수술실패여부': 0,
#   '수술일자': 20200107,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 10.0,
#   '후방디스크높이(mm)': 8.0,
#   '지방축적도': 222.7,
#   'Instability': 0,
#   'MF + ES': 1514.2,
#   'Modic change': 0,
#   'PI': 53.4,
#   'PT': 29.0,
#   'Seg Angle(raw)': 8.3,
#   'Vaccum disc': 0,
#   '골밀도': -1.92,
#   '디스크단면적': 1626.7,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 33,
#   '환자ID': '34PT',
#   'Large Lymphocyte': 46.7,
#   'Location of herniation': 3,
#   'ODI': 27.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 178,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 57,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20200205,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 77.5,
#   '퇴원일자': 20200209,
#   '헤모글로빈수치': 12.69,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 3.0,
#   '수술기법': 'TELD',
#   '수술시간': 50.0,
#   '수술실패여부': 0,
#   '수술일자': 20200208,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 11.8,
#   '후방디스크높이(mm)': 6.9,
#   '지방축적도': 112.0,
#   'Instability': 0,
#   'MF + ES': 2286.7,
#   'Modic change': 0,
#   'PI': 36.1,
#   'PT': 9.9,
#   'Seg Angle(raw)': 14.0,
#   'Vaccum disc': 0,
#   '골밀도': -1.71,
#   '디스크단면적': 2100.0,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 34,
#   '환자ID': '35PT',
#   'Large Lymphocyte': 50.2,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 171,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 40,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200209,
#   '종양진행여부': 0,
#   '직업': '의료직',
#   '체중': 71.9,
#   '퇴원일자': 20200210,
#   '헤모글로빈수치': 16.47,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 80.0,
#   '수술실패여부': 0,
#   '수술일자': 20200210,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 10.9,
#   '후방디스크높이(mm)': 9.6,
#   '지방축적도': 172.5,
#   'Instability': 0,
#   'MF + ES': 1633.6,
#   'Modic change': 0,
#   'PI': 66.7,
#   'PT': 31.0,
#   'Seg Angle(raw)': 17.2,
#   'Vaccum disc': 0,
#   '골밀도': -1.97,
#   '디스크단면적': 1618.4,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 35,
#   '환자ID': '36PT',
#   'Large Lymphocyte': 39.0,
#   'Location of herniation': 3,
#   'ODI': 42.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 156,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 37,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200215,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 58.1,
#   '퇴원일자': 20200217,
#   '헤모글로빈수치': 13.92,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 87.0,
#   '수술실패여부': 0,
#   '수술일자': 20200216,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 12.0,
#   '후방디스크높이(mm)': 10.3,
#   '지방축적도': 296.6,
#   'Instability': 0,
#   'MF + ES': 1729.7,
#   'Modic change': 0,
#   'PI': 55.3,
#   'PT': 29.0,
#   'Seg Angle(raw)': 15.3,
#   'Vaccum disc': 0,
#   '골밀도': -2.12,
#   '디스크단면적': 1751.6,
#   '디스크위치': 4,
#   '척추이동척도': 'Up',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 36,
#   '환자ID': '37PT',
#   'Large Lymphocyte': 25.2,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 157,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 76,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20200229,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 58.2,
#   '퇴원일자': 20200304,
#   '헤모글로빈수치': 9.95,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'IELD',
#   '수술시간': 54.0,
#   '수술실패여부': 0,
#   '수술일자': 20200303,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 9.9,
#   '후방디스크높이(mm)': 3.4,
#   '지방축적도': 109.8,
#   'Instability': 0,
#   'MF + ES': 1669.7,
#   'Modic change': 0,
#   'PI': 31.8,
#   'PT': 6.0,
#   'Seg Angle(raw)': 16.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.17,
#   '디스크단면적': 2086.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 37,
#   '환자ID': '38PT',
#   'Large Lymphocyte': 46.0,
#   'Location of herniation': 4,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 167,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 52,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200317,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 61.6,
#   '퇴원일자': 20200319,
#   '헤모글로빈수치': 17.42,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 58.0,
#   '수술실패여부': 0,
#   '수술일자': 20200319,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 17.9,
#   '후방디스크높이(mm)': 8.5,
#   '지방축적도': 268.5,
#   'Instability': 0,
#   'MF + ES': 2288.5,
#   'Modic change': 0,
#   'PI': 37.6,
#   'PT': 15.6,
#   'Seg Angle(raw)': 21.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.1,
#   '디스크단면적': 3137.0,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 38,
#   '환자ID': '39PT',
#   'Large Lymphocyte': 52.3,
#   'Location of herniation': 3,
#   'ODI': 27.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 178,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 29,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200419,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 76.8,
#   '퇴원일자': 20200420,
#   '헤모글로빈수치': 13.17,
#   '혈전합병증여부': 0,
#   '환자통증정도': 9,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 60.0,
#   '수술실패여부': 0,
#   '수술일자': 20200420,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 13.9,
#   '후방디스크높이(mm)': 7.5,
#   '지방축적도': 107.5,
#   'Instability': 0,
#   'MF + ES': 1897.1,
#   'Modic change': 0,
#   'PI': 54.2,
#   'PT': 17.1,
#   'Seg Angle(raw)': 25.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.18,
#   '디스크단면적': 1665.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 39,
#   '환자ID': '40PT',
#   'Large Lymphocyte': 45.5,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 156,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 49,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20200625,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 57.9,
#   '퇴원일자': 20200628,
#   '헤모글로빈수치': 15.5,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 70.0,
#   '수술실패여부': 0,
#   '수술일자': 20200628,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 12.4,
#   '후방디스크높이(mm)': 9.7,
#   '지방축적도': 204.0,
#   'Instability': 0,
#   'MF + ES': 1277.9,
#   'Modic change': 2,
#   'PI': 38.2,
#   'PT': 3.8,
#   'Seg Angle(raw)': 13.4,
#   'Vaccum disc': 0,
#   '골밀도': -0.69,
#   '디스크단면적': 2250.4,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 40,
#   '환자ID': '41PT',
#   'Large Lymphocyte': 42.7,
#   'Location of herniation': 5,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 1,
#   '신장': 182,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 50,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20200726,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 80.2,
#   '퇴원일자': 20200729,
#   '헤모글로빈수치': 13.41,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 67.0,
#   '수술실패여부': 0,
#   '수술일자': 20200728,
#   '재발여부': 1,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 15.8,
#   '후방디스크높이(mm)': 8.5,
#   '지방축적도': 71.1,
#   'Instability': 0,
#   'MF + ES': 1747.2,
#   'Modic change': 2,
#   'PI': 35.8,
#   'PT': 16.1,
#   'Seg Angle(raw)': 14.6,
#   'Vaccum disc': 0,
#   '골밀도': -1.98,
#   '디스크단면적': 2040.7,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 41,
#   '환자ID': '42PT',
#   'Large Lymphocyte': 22.0,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 151,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 57,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190218,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 56.0,
#   '퇴원일자': 20190220,
#   '헤모글로빈수치': 13.4,
#   '혈전합병증여부': 0,
#   '환자통증정도': 2,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 59.0,
#   '수술실패여부': 0,
#   '수술일자': 20190219,
#   '재발여부': 1,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 9.39,
#   '후방디스크높이(mm)': 7.62,
#   '지방축적도': 100.01,
#   'Instability': 0,
#   'MF + ES': 2503.34,
#   'Modic change': 0,
#   'PI': 46.0,
#   'PT': 24.0,
#   'Seg Angle(raw)': 6.0,
#   'Vaccum disc': 1,
#   '골밀도': -2.33,
#   '디스크단면적': 1602.69,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 42,
#   '환자ID': '43PT',
#   'Large Lymphocyte': 40.0,
#   'Location of herniation': 4,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 1,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 171,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 50,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190310,
#   '종양진행여부': 0,
#   '직업': '사업가',
#   '체중': 72.1,
#   '퇴원일자': 20190314,
#   '헤모글로빈수치': 13.03,
#   '혈전합병증여부': 0,
#   '환자통증정도': 1,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 63.0,
#   '수술실패여부': 0,
#   '수술일자': 20190313,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 15.28,
#   '후방디스크높이(mm)': 8.81,
#   '지방축적도': 121.03,
#   'Instability': 0,
#   'MF + ES': 2763.94,
#   'Modic change': 0,
#   'PI': 44.0,
#   'PT': 9.0,
#   'Seg Angle(raw)': 28.0,
#   'Vaccum disc': 0,
#   '골밀도': -0.96,
#   '디스크단면적': 2008.74,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 43,
#   '환자ID': '44PT',
#   'Large Lymphocyte': 38.0,
#   'Location of herniation': 2,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 173,
#   '심혈관질환': 1,
#   '암발병여부': 0,
#   '연령': 39,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190405,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 73.6,
#   '퇴원일자': 20190407,
#   '헤모글로빈수치': 13.18,
#   '혈전합병증여부': 0,
#   '환자통증정도': 1,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'IELD',
#   '수술시간': 65.0,
#   '수술실패여부': 0,
#   '수술일자': 20190407,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 11.19,
#   '후방디스크높이(mm)': 8.79,
#   '지방축적도': 107.51,
#   'Instability': 0,
#   'MF + ES': 3679.32,
#   'Modic change': 0,
#   'PI': 47.0,
#   'PT': 16.0,
#   'Seg Angle(raw)': 3.0,
#   'Vaccum disc': 1,
#   '골밀도': -1.66,
#   '디스크단면적': 2345.14,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 44,
#   '환자ID': '45PT',
#   'Large Lymphocyte': 35.8,
#   'Location of herniation': 2,
#   'ODI': 28.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 157,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 46,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190503,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 58.3,
#   '퇴원일자': 20190504,
#   '헤모글로빈수치': 12.3,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 90.0,
#   '수술실패여부': 0,
#   '수술일자': 20190504,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 13.9,
#   '후방디스크높이(mm)': 9.5,
#   '지방축적도': 241.6,
#   'Instability': 0,
#   'MF + ES': 1854.0,
#   'Modic change': 2,
#   'PI': 52.8,
#   'PT': 21.9,
#   'Seg Angle(raw)': 7.7,
#   'Vaccum disc': 0,
#   '골밀도': -1.17,
#   '디스크단면적': 1678.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 45,
#   '환자ID': '46PT',
#   'Large Lymphocyte': 10.5,
#   'Location of herniation': 2,
#   'ODI': 44.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 160,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 77,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190524,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 59.3,
#   '퇴원일자': 20190526,
#   '헤모글로빈수치': 13.74,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 121.0,
#   '수술실패여부': 0,
#   '수술일자': 20190525,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 13.3,
#   '후방디스크높이(mm)': 11.7,
#   '지방축적도': 318.6,
#   'Instability': 0,
#   'MF + ES': 2425.8,
#   'Modic change': 0,
#   'PI': 49.7,
#   'PT': 27.6,
#   'Seg Angle(raw)': 1.2,
#   'Vaccum disc': 0,
#   '골밀도': -2.21,
#   '디스크단면적': 2155.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 46,
#   '환자ID': '47PT',
#   'Large Lymphocyte': 54.1,
#   'Location of herniation': 2,
#   'ODI': 18.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 170,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 72,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190621,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 71.3,
#   '퇴원일자': 20190622,
#   '헤모글로빈수치': 15.41,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 68.0,
#   '수술실패여부': 0,
#   '수술일자': 20190622,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 13.4,
#   '후방디스크높이(mm)': 7.5,
#   '지방축적도': 121.3,
#   'Instability': 0,
#   'MF + ES': 2501.4,
#   'Modic change': 0,
#   'PI': 47.0,
#   'PT': 5.7,
#   'Seg Angle(raw)': 4.4,
#   'Vaccum disc': 0,
#   '골밀도': -2.02,
#   '디스크단면적': 1718.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 47,
#   '환자ID': '48PT',
#   'Large Lymphocyte': 55.5,
#   'Location of herniation': 3,
#   'ODI': 40.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 160,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 54,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190730,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 59.1,
#   '퇴원일자': 20190802,
#   '헤모글로빈수치': 12.15,
#   '혈전합병증여부': 0,
#   '환자통증정도': 10,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 48.0,
#   '수술실패여부': 0,
#   '수술일자': 20190801,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 14.0,
#   '후방디스크높이(mm)': 6.9,
#   '지방축적도': 172.9,
#   'Instability': 0,
#   'MF + ES': 1772.2,
#   'Modic change': 0,
#   'PI': 56.6,
#   'PT': 11.6,
#   'Seg Angle(raw)': 7.5,
#   'Vaccum disc': 0,
#   '골밀도': -1.75,
#   '디스크단면적': 1476.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 48,
#   '환자ID': '49PT',
#   'Large Lymphocyte': 46.7,
#   'Location of herniation': 3,
#   'ODI': 21.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 175,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 69,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20190127,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 75.2,
#   '퇴원일자': 20190128,
#   '헤모글로빈수치': 15.01,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 63.0,
#   '수술실패여부': 0,
#   '수술일자': 20190128,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 17.2,
#   '후방디스크높이(mm)': 8.3,
#   '지방축적도': 153.7,
#   'Instability': 0,
#   'MF + ES': 2677.2,
#   'Modic change': 0,
#   'PI': 36.3,
#   'PT': 4.5,
#   'Seg Angle(raw)': 7.3,
#   'Vaccum disc': 0,
#   '골밀도': -1.69,
#   '디스크단면적': 2143.1,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 49,
#   '환자ID': '50PT',
#   'Large Lymphocyte': 47.9,
#   'Location of herniation': 2,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 160,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 56,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190210,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 59.2,
#   '퇴원일자': 20190212,
#   '헤모글로빈수치': 17.43,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 111.0,
#   '수술실패여부': 0,
#   '수술일자': 20190212,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 19.2,
#   '후방디스크높이(mm)': 9.5,
#   '지방축적도': 139.7,
#   'Instability': 0,
#   'MF + ES': 2925.2,
#   'Modic change': 0,
#   'PI': 40.8,
#   'PT': 7.5,
#   'Seg Angle(raw)': 10.7,
#   'Vaccum disc': 0,
#   '골밀도': -1.51,
#   '디스크단면적': 2263.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 50,
#   '환자ID': '51PT',
#   'Large Lymphocyte': 31.5,
#   'Location of herniation': 4,
#   'ODI': 14.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 169,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 55,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190402,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 70.1,
#   '퇴원일자': 20190403,
#   '헤모글로빈수치': 15.7,
#   '혈전합병증여부': 0,
#   '환자통증정도': 6,
#   '흡연여부': 1,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 98.0,
#   '수술실패여부': 0,
#   '수술일자': 20190403,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 13.7,
#   '후방디스크높이(mm)': 7.6,
#   '지방축적도': 104.3,
#   'Instability': 0,
#   'MF + ES': 3755.4,
#   'Modic change': 0,
#   'PI': 44.1,
#   'PT': 20.5,
#   'Seg Angle(raw)': 4.7,
#   'Vaccum disc': 0,
#   '골밀도': -1.72,
#   '디스크단면적': 1899.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 51,
#   '환자ID': '52PT',
#   'Large Lymphocyte': 26.7,
#   'Location of herniation': 3,
#   'ODI': 37.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 161,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 38,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190429,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 63.8,
#   '퇴원일자': 20190501,
#   '헤모글로빈수치': 17.25,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 81.0,
#   '수술실패여부': 0,
#   '수술일자': 20190501,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 17.8,
#   '후방디스크높이(mm)': 11.4,
#   '지방축적도': 118.7,
#   'Instability': 0,
#   'MF + ES': 1988.5,
#   'Modic change': 0,
#   'PI': 38.7,
#   'PT': 16.4,
#   'Seg Angle(raw)': 5.7,
#   'Vaccum disc': 0,
#   '골밀도': -1.86,
#   '디스크단면적': 2118.4,
#   '디스크위치': 3,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 52,
#   '환자ID': '53PT',
#   'Large Lymphocyte': 36.9,
#   'Location of herniation': 3,
#   'ODI': 36.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 168,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 29,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20190524,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 69.6,
#   '퇴원일자': 20190526,
#   '헤모글로빈수치': 16.42,
#   '혈전합병증여부': 0,
#   '환자통증정도': 9,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 47.0,
#   '수술실패여부': 0,
#   '수술일자': 20190526,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 10.0,
#   '후방디스크높이(mm)': 5.1,
#   '지방축적도': 177.7,
#   'Instability': 0,
#   'MF + ES': 3057.2,
#   'Modic change': 0,
#   'PI': 61.5,
#   'PT': 29.2,
#   'Seg Angle(raw)': 5.1,
#   'Vaccum disc': 0,
#   '골밀도': -1.43,
#   '디스크단면적': 2118.6,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 53,
#   '환자ID': '54PT',
#   'Large Lymphocyte': 38.6,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 185,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 40,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20190624,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 82.7,
#   '퇴원일자': 20190625,
#   '헤모글로빈수치': 17.49,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 59.0,
#   '수술실패여부': 0,
#   '수술일자': 20190625,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 14.6,
#   '후방디스크높이(mm)': 7.2,
#   '지방축적도': 119.1,
#   'Instability': 0,
#   'MF + ES': 2121.2,
#   'Modic change': 0,
#   'PI': 33.6,
#   'PT': 10.6,
#   'Seg Angle(raw)': 7.0,
#   'Vaccum disc': 0,
#   '골밀도': -1.1,
#   '디스크단면적': 2099.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 54,
#   '환자ID': '55PT',
#   'Large Lymphocyte': 86.1,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 168,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 38,
#   '우울증여부': 0,
# ...
#   '골밀도': nan,
#   '디스크단면적': 2119.3,
#   '디스크위치': 5,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 982,
#   '환자ID': '983PT',
#   'Large Lymphocyte': 53.2,
#   'Location of herniation': 3,
#   'ODI': 39.0,
#   '가족력': 1.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 2,
#   '당뇨여부': 1,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 170,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 56,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20090402,
#   '종양진행여부': 0,
#   '직업': '운수업',
#   '체중': 75.0,
#   '퇴원일자': 20090406,
#   '헤모글로빈수치': 15.4,
#   '혈전합병증여부': 0,
#   '환자통증정도': 10,
#   '흡연여부': 0,
#   '통증기간(월)': 5.0,
#   '수술기법': 'TELD',
#   '수술시간': 40.0,
#   '수술실패여부': 0,
#   '수술일자': 20090406,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 12.5,
#   '후방디스크높이(mm)': 6.8,
#   '지방축적도': 104.4,
#   'Instability': 0,
#   'MF + ES': 2636.91,
#   'Modic change': 2,
#   'PI': 37.2,
#   'PT': 8.9,
#   'Seg Angle(raw)': 13.5,
#   'Vaccum disc': 1,
#   '골밀도': nan,
#   '디스크단면적': 2119.3,
#   '디스크위치': 5,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 983,
#   '환자ID': '984PT',
#   'Large Lymphocyte': 50.5,
#   'Location of herniation': 3,
#   'ODI': 26.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 1,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 151,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 74,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20110107,
#   '종양진행여부': 0,
#   '직업': '무직',
#   '체중': 59.0,
#   '퇴원일자': 20110108,
#   '헤모글로빈수치': 10.6,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 0,
#   '통증기간(월)': 18.0,
#   '수술기법': 'TELD',
#   '수술시간': 35.0,
#   '수술실패여부': 0,
#   '수술일자': 20110107,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 9.2,
#   '후방디스크높이(mm)': 6.7,
#   '지방축적도': 728.6,
#   'Instability': 1,
#   'MF + ES': 1629.0,
#   'Modic change': 2,
#   'PI': 48.1,
#   'PT': 9.1,
#   'Seg Angle(raw)': 19.5,
#   'Vaccum disc': 1,
#   '골밀도': -1.8,
#   '디스크단면적': 2126.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 1},
#  {'Unnamed: 0': 984,
#   '환자ID': '985PT',
#   'Large Lymphocyte': 24.1,
#   'Location of herniation': 3,
#   'ODI': 37.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 1,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 176,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 42,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20091108,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 88.0,
#   '퇴원일자': 20091110,
#   '헤모글로빈수치': 13.0,
#   '혈전합병증여부': 0,
#   '환자통증정도': 9,
#   '흡연여부': 0,
#   '통증기간(월)': 3.0,
#   '수술기법': 'TELD',
#   '수술시간': 65.0,
#   '수술실패여부': 0,
#   '수술일자': 20091109,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 8.9,
#   '후방디스크높이(mm)': 6.8,
#   '지방축적도': 149.6,
#   'Instability': 1,
#   'MF + ES': 2313.3,
#   'Modic change': 2,
#   'PI': 53.9,
#   'PT': 30.2,
#   'Seg Angle(raw)': 7.0,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 1894.5,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 985,
#   '환자ID': '986PT',
#   'Large Lymphocyte': 20.3,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 178,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 35,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20120103,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 82.0,
#   '퇴원일자': 20120104,
#   '헤모글로빈수치': 17.1,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 21.0,
#   '수술기법': 'TELD',
#   '수술시간': 35.0,
#   '수술실패여부': 0,
#   '수술일자': 20120104,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 9.6,
#   '후방디스크높이(mm)': 7.3,
#   '지방축적도': 61.0,
#   'Instability': 1,
#   'MF + ES': 1967.7,
#   'Modic change': 2,
#   'PI': 42.9,
#   'PT': 21.3,
#   'Seg Angle(raw)': 9.1,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 1915.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 986,
#   '환자ID': '987PT',
#   'Large Lymphocyte': 59.4,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 174,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 52,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20120613,
#   '종양진행여부': 0,
#   '직업': nan,
#   '체중': 74.0,
#   '퇴원일자': 20120615,
#   '헤모글로빈수치': 15.5,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 0.5,
#   '수술기법': 'TELD',
#   '수술시간': 40.0,
#   '수술실패여부': 0,
#   '수술일자': 20120613,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 14.3,
#   '후방디스크높이(mm)': 9.1,
#   '지방축적도': 499.8,
#   'Instability': 0,
#   'MF + ES': 1878.5,
#   'Modic change': 1,
#   'PI': 61.6,
#   'PT': 19.0,
#   'Seg Angle(raw)': 17.0,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 1642.2,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 987,
#   '환자ID': '988PT',
#   'Large Lymphocyte': 32.1,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 181,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 53,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20110404,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 81.0,
#   '퇴원일자': 20110406,
#   '헤모글로빈수치': 14.9,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 70.0,
#   '수술실패여부': 0,
#   '수술일자': 20110405,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 14.4,
#   '후방디스크높이(mm)': 8.3,
#   '지방축적도': 252.8,
#   'Instability': 0,
#   'MF + ES': 2012.5,
#   'Modic change': 0,
#   'PI': 49.9,
#   'PT': 17.1,
#   'Seg Angle(raw)': 23.8,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2268.5,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 1},
#  {'Unnamed: 0': 988,
#   '환자ID': '989PT',
#   'Large Lymphocyte': 56.3,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 166,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 63,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20160418,
#   '종양진행여부': 0,
#   '직업': '무직',
#   '체중': 70.0,
#   '퇴원일자': 20160503,
#   '헤모글로빈수치': 12.4,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 5.0,
#   '수술기법': 'TELD',
#   '수술시간': 45.0,
#   '수술실패여부': 1,
#   '수술일자': 20160419,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 17.9,
#   '후방디스크높이(mm)': 13.7,
#   '지방축적도': 121.0,
#   'Instability': 0,
#   'MF + ES': 1798.2,
#   'Modic change': 0,
#   'PI': 62.8,
#   'PT': 23.3,
#   'Seg Angle(raw)': 21.3,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2199.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 989,
#   '환자ID': '990PT',
#   'Large Lymphocyte': 23.3,
#   'Location of herniation': 4,
#   'ODI': 22.0,
#   '가족력': 1.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 1,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 171,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 37,
#   '우울증여부': 0,
#   '입원기간': 4,
#   '입원일자': 20090120,
#   '종양진행여부': 0,
#   '직업': '공무원',
#   '체중': 68.0,
#   '퇴원일자': 20090124,
#   '헤모글로빈수치': 15.1,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 16.0,
#   '수술기법': 'TELD',
#   '수술시간': 50.0,
#   '수술실패여부': 0,
#   '수술일자': 20090120,
#   '재발여부': 0,
#   '혈액형': 'RH+AB',
#   '전방디스크높이(mm)': 10.5,
#   '후방디스크높이(mm)': 5.41,
#   '지방축적도': 121.0,
#   'Instability': 0,
#   'MF + ES': 1199.0,
#   'Modic change': 2,
#   'PI': 40.2,
#   'PT': 14.1,
#   'Seg Angle(raw)': 13.8,
#   'Vaccum disc': 0,
#   '골밀도': -1.0,
#   '디스크단면적': 2155.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 990,
#   '환자ID': '991PT',
#   'Large Lymphocyte': 45.4,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 167,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 54,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20170403,
#   '종양진행여부': 0,
#   '직업': '자영업',
#   '체중': 70.0,
#   '퇴원일자': 20170404,
#   '헤모글로빈수치': 16.5,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 3.0,
#   '수술기법': 'TELD',
#   '수술시간': 80.0,
#   '수술실패여부': 0,
#   '수술일자': 20170403,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 18.1,
#   '후방디스크높이(mm)': 9.6,
#   '지방축적도': 87.6,
#   'Instability': 0,
#   'MF + ES': 1746.3,
#   'Modic change': 0,
#   'PI': 38.8,
#   'PT': 12.7,
#   'Seg Angle(raw)': 14.7,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2408.9,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 991,
#   '환자ID': '992PT',
#   'Large Lymphocyte': 51.1,
#   'Location of herniation': 2,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 155,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 64,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20170924,
#   '종양진행여부': 0,
#   '직업': '무직',
#   '체중': 61.0,
#   '퇴원일자': 20170926,
#   '헤모글로빈수치': 14.4,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 8.0,
#   '수술기법': 'TELD',
#   '수술시간': 60.0,
#   '수술실패여부': 0,
#   '수술일자': 20170925,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 14.0,
#   '후방디스크높이(mm)': 8.2,
#   '지방축적도': 253.1,
#   'Instability': 0,
#   'MF + ES': 1930.7,
#   'Modic change': 0,
#   'PI': 65.9,
#   'PT': 17.5,
#   'Seg Angle(raw)': 14.8,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2079.0,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 992,
#   '환자ID': '993PT',
#   'Large Lymphocyte': 40.4,
#   'Location of herniation': 2,
#   'ODI': 19.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 169,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 58,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20140513,
#   '종양진행여부': 0,
#   '직업': '농업',
#   '체중': 68.0,
#   '퇴원일자': 20140523,
#   '헤모글로빈수치': 13.6,
#   '혈전합병증여부': 0,
#   '환자통증정도': 10,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 140.0,
#   '수술실패여부': 0,
#   '수술일자': 20140519,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 12.8,
#   '후방디스크높이(mm)': 9.3,
#   '지방축적도': 144.0,
#   'Instability': 0,
#   'MF + ES': 1209.8,
#   'Modic change': 0,
#   'PI': 63.8,
#   'PT': 27.8,
#   'Seg Angle(raw)': 20.1,
#   'Vaccum disc': 0,
#   '골밀도': -1.5,
#   '디스크단면적': 1912.1,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 993,
#   '환자ID': '994PT',
#   'Large Lymphocyte': 44.6,
#   'Location of herniation': 2,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 165,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 52,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20120222,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 76.0,
#   '퇴원일자': 20120224,
#   '헤모글로빈수치': 17.2,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 1,
#   '통증기간(월)': 4.0,
#   '수술기법': 'TELD',
#   '수술시간': 40.0,
#   '수술실패여부': 0,
#   '수술일자': 20120223,
#   '재발여부': 0,
#   '혈액형': 'RH+A',
#   '전방디스크높이(mm)': 19.6,
#   '후방디스크높이(mm)': 10.2,
#   '지방축적도': 184.6,
#   'Instability': 0,
#   'MF + ES': 2152.3,
#   'Modic change': 2,
#   'PI': 32.0,
#   'PT': 12.6,
#   'Seg Angle(raw)': 11.1,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 1750.8,
#   '디스크위치': 4,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 994,
#   '환자ID': '995PT',
#   'Large Lymphocyte': 39.2,
#   'Location of herniation': 3,
#   'ODI': 26.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 177,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 30,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20091029,
#   '종양진행여부': 0,
#   '직업': '건설업',
#   '체중': 103.0,
#   '퇴원일자': 20091030,
#   '헤모글로빈수치': 15.6,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 3.0,
#   '수술기법': 'IELD',
#   '수술시간': 45.0,
#   '수술실패여부': 0,
#   '수술일자': 20091030,
#   '재발여부': 0,
#   '혈액형': 'RH+B',
#   '전방디스크높이(mm)': 12.7,
#   '후방디스크높이(mm)': 7.8,
#   '지방축적도': 220.5,
#   'Instability': 0,
#   'MF + ES': 2101.3,
#   'Modic change': 0,
#   'PI': 37.1,
#   'PT': 11.9,
#   'Seg Angle(raw)': 11.9,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2056.6,
#   '디스크위치': 5,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 995,
#   '환자ID': '996PT',
#   'Large Lymphocyte': 24.6,
#   'Location of herniation': 3,
#   'ODI': 10.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 167,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 57,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20120227,
#   '종양진행여부': 0,
#   '직업': '무직',
#   '체중': 61.0,
#   '퇴원일자': 20120229,
#   '헤모글로빈수치': 16.7,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 0.5,
#   '수술기법': 'TELD',
#   '수술시간': 50.0,
#   '수술실패여부': 1,
#   '수술일자': 20120227,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 11.2,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 137.6,
#   'Instability': 0,
#   'MF + ES': 1576.6,
#   'Modic change': 2,
#   'PI': 49.0,
#   'PT': 31.4,
#   'Seg Angle(raw)': 2.6,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2299.1,
#   '디스크위치': 3,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 996,
#   '환자ID': '997PT',
#   'Large Lymphocyte': 24.6,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 167,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 57,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20120227,
#   '종양진행여부': 0,
#   '직업': '무직',
#   '체중': 61.0,
#   '퇴원일자': 20120229,
#   '헤모글로빈수치': 16.7,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': nan,
#   '수술기법': 'TELD',
#   '수술시간': 45.0,
#   '수술실패여부': 0,
#   '수술일자': 20120228,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 11.2,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 137.6,
#   'Instability': 0,
#   'MF + ES': 1576.6,
#   'Modic change': 2,
#   'PI': 49.0,
#   'PT': 31.4,
#   'Seg Angle(raw)': 2.6,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 2299.1,
#   '디스크위치': 3,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 997,
#   '환자ID': '998PT',
#   'Large Lymphocyte': 59.2,
#   'Location of herniation': 3,
#   'ODI': 30.0,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 0,
#   '과거수술횟수': 0,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 0,
#   '신부전여부': 0,
#   '신장': 170,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 40,
#   '우울증여부': 0,
#   '입원기간': 1,
#   '입원일자': 20110727,
#   '종양진행여부': 0,
#   '직업': '의료직',
#   '체중': 66.0,
#   '퇴원일자': 20120229,
#   '헤모글로빈수치': 13.6,
#   '혈전합병증여부': 0,
#   '환자통증정도': 8,
#   '흡연여부': 0,
#   '통증기간(월)': 1.0,
#   '수술기법': 'TELD',
#   '수술시간': 45.0,
#   '수술실패여부': 0,
#   '수술일자': 20110727,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 14.3,
#   '후방디스크높이(mm)': 8.0,
#   '지방축적도': 394.1,
#   'Instability': 0,
#   'MF + ES': 1724.5,
#   'Modic change': 2,
#   'PI': 61.0,
#   'PT': 16.4,
#   'Seg Angle(raw)': 23.2,
#   'Vaccum disc': 0,
#   '골밀도': nan,
#   '디스크단면적': 1744.3,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 998,
#   '환자ID': '999PT',
#   'Large Lymphocyte': 28.5,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 2,
#   '당뇨여부': 0,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 1,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 180,
#   '심혈관질환': 0,
#   '암발병여부': 0,
#   '연령': 37,
#   '우울증여부': 0,
#   '입원기간': 3,
#   '입원일자': 20171019,
#   '종양진행여부': 0,
#   '직업': '사무직',
#   '체중': 88.0,
#   '퇴원일자': 20120229,
#   '헤모글로빈수치': 16.7,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 3.0,
#   '수술기법': 'TELD',
#   '수술시간': 105.0,
#   '수술실패여부': 0,
#   '수술일자': 20171020,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 13.8,
#   '후방디스크높이(mm)': 8.7,
#   '지방축적도': 120.5,
#   'Instability': 1,
#   'MF + ES': 2688.8,
#   'Modic change': 0,
#   'PI': 41.8,
#   'PT': 20.8,
#   'Seg Angle(raw)': 10.3,
#   'Vaccum disc': 1,
#   '골밀도': nan,
#   '디스크단면적': 2205.2,
#   '디스크위치': 4,
#   '척추이동척도': 'Down',
#   '척추전방위증': 0},
#  {'Unnamed: 0': 999,
#   '환자ID': '1000PT',
#   'Large Lymphocyte': 36.6,
#   'Location of herniation': 3,
#   'ODI': nan,
#   '가족력': 0.0,
#   '간질성폐질환': 0,
#   '고혈압여부': 1,
#   '과거수술횟수': 0,
#   '당뇨여부': 1,
#   '말초동맥질환여부': 0,
#   '빈혈여부': 0,
#   '성별': 2,
#   '스테로이드치료': 1,
#   '신부전여부': 0,
#   '신장': 160,
#   '심혈관질환': 1,
#   '암발병여부': 0,
#   '연령': 76,
#   '우울증여부': 0,
#   '입원기간': 2,
#   '입원일자': 20160303,
#   '종양진행여부': 0,
#   '직업': '주부',
#   '체중': 57.0,
#   '퇴원일자': 20120229,
#   '헤모글로빈수치': 15.1,
#   '혈전합병증여부': 0,
#   '환자통증정도': 7,
#   '흡연여부': 0,
#   '통증기간(월)': 2.0,
#   '수술기법': 'TELD',
#   '수술시간': 60.0,
#   '수술실패여부': 0,
#   '수술일자': 20160303,
#   '재발여부': 0,
#   '혈액형': 'RH+O',
#   '전방디스크높이(mm)': 14.6,
#   '후방디스크높이(mm)': 7.4,
#   '지방축적도': 289.2,
#   'Instability': 0,
#   'MF + ES': 1016.8,
#   'Modic change': 0,
#   'PI': 57.1,
#   'PT': 24.4,
#   'Seg Angle(raw)': 13.6,
#   'Vaccum disc': 1,
#   '골밀도': -1.8,
#   '디스크단면적': 1511.7,
#   '디스크위치': 3,
#   '척추이동척도': 'Middle',
#   '척추전방위증': 0},
#  ...]

# %%
type(data_list)
# Out:
# list

# %%
collection.insert_many(data_list)
