# %%
# %conda install pymongo
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\01-09\anaconda3
#
#   added / updated specs:
#     - pymongo
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pymongo-3.12.0             |  py311hd77b12b_0         1.5 MB
#     ------------------------------------------------------------
#                                            Total:         1.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   pymongo            pkgs/main/win-64::pymongo-3.12.0-py311hd77b12b_0
#
#
#
# ...
#
# pymongo-3.12.0       | 1.5 MB    |            |   0%
# pymongo-3.12.0       | 1.5 MB    | ####3      |  44%
# pymongo-3.12.0       | 1.5 MB    | ########## | 100%
# pymongo-3.12.0       | 1.5 MB    | ########## | 100%
#
#
#
# Preparing transaction: ...working... done
# ...

# %% [markdown]
# ### 몽고db 데이터 불러오는 방법

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
mg.MongoClient(host=mongodb://localhost:27017)
# Out:
#   Cell In[4], line 1
#     mg.MongoClient(host=mongodb://localhost:27017)
#                                ^
# SyntaxError: invalid syntax

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BND']

# %%
cursor = collection.find({})

# %%
list_BND = list(cursor)

# %%
list_BND
# Out:
# [{'_id': ObjectId('64d2fd14152e7e5b718ecc27'),
#   'RN_INDI': 294364,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200707,
#   'COD1': 'T08-T14',
#   'COD2': 'W00-W19'},
#  {'_id': ObjectId('64d2fd14152e7e5b718ecc28'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19'},
#  {'_id': ObjectId('64d2fd14152e7e5b718ecc29'),
#   'RN_INDI': 733575,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201309,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd14152e7e5b718ecc2a'),
#   'RN_INDI': 966199,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201409,
#   'COD1': 'J69'},
#  {'_id': ObjectId('64d2fd14152e7e5b718ecc2b'),
#   'RN_INDI': 972598,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C44'},
#  {'_id': ObjectId('64d2fd14152e7e5b718ecc2c'),
#   'RN_INDI': 979888,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201101,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd14152e7e5b718ecc2d'),
#   'RN_INDI': 991645,
#   'BTH_YYYY': '1921LE',
# ...

# %%
df_BND = pd.DataFrame(list_BND)

# %%
df_BND
# Out:
#                           _id  RN_INDI BTH_YYYY  DTH_YYYYMM     COD1     COD2
# 0    64d2fd14152e7e5b718ecc27   294364   1921LE    200707.0  T08-T14  W00-W19
# 1    64d2fd14152e7e5b718ecc28   646257   1921LE    200805.0  A15-A19      NaN
# 2    64d2fd14152e7e5b718ecc29   733575   1921LE    201309.0      G30      NaN
# 3    64d2fd14152e7e5b718ecc2a   966199   1921LE    201409.0      J69      NaN
# 4    64d2fd14152e7e5b718ecc2b   972598   1921LE    201205.0      C44      NaN
# ..                        ...      ...      ...         ...      ...      ...
# 995  64d2fd14152e7e5b718ed00a  2057743     2015         NaN      NaN      NaN
# 996  64d2fd14152e7e5b718ed00b  2063541     2015         NaN      NaN      NaN
# 997  64d2fd14152e7e5b718ed00c  2070251     2015         NaN      NaN      NaN
# 998  64d2fd14152e7e5b718ed00d  2077125     2015         NaN      NaN      NaN
# 999  64d2fd14152e7e5b718ed00e  3000758     2015         NaN      NaN      NaN
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### 몽고db에 있는 데이터 부르고 쥬피터랩에 저장하는 방법.
# to_저장파일형식선택('./(저장될 위치선택)파일이름.파일형식')

# %%
df_BND.to_csv('./NSC2_BND.csv')
