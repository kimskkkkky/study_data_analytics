# %%
import pymongo as mg
import pandas as pd

# %%
client = mg.MongoClient(host= 'mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_BNC_V2_1']

# %%
cursor = collection.find({})

# %%
list_BNC = list(cursor)

# %%
list_BNC
# Out:
# [{'_id': ObjectId('64d311d91202dc332c55fedf'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee0'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee1'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee2'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee3'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee4'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee5'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee6'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee7'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee8'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fee9'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feea'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feeb'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feec'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 47190,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feed'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feee'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feef'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef0'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41460,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef1'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef2'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef3'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef4'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 41461,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef5'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef6'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef7'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef8'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fef9'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fefa'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 3085,
#   'SEX': 2,
#   'SGG': 44760,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fefb'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fefc'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fefd'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55fefe'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55feff'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff00'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff01'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff02'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff03'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff04'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff05'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff06'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff07'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff08'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 4316,
#   'SEX': 1,
#   'SGG': 47130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff09'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff0a'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff0b'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff0c'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff0d'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff0e'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41220,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff0f'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff10'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff11'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 11650,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff12'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff13'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 4392,
#   'SEX': 2,
#   'SGG': 41590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff14'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff15'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff16'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff17'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26320,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff18'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff19'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff1a'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26140,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff1b'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26410,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff1c'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff1d'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff1e'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff1f'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff20'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 5835,
#   'SEX': 2,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff21'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff22'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff23'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff24'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff25'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff26'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff27'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff28'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff29'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff2a'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff2b'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff2c'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff2d'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff2e'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6088,
#   'SEX': 1,
#   'SGG': 46770,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff2f'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff30'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff31'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff32'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff33'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff34'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff35'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff36'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff37'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff38'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff39'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff3a'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff3b'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff3c'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6091,
#   'SEX': 1,
#   'SGG': 27170,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff3d'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff3e'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff3f'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff40'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff41'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff42'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff43'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff44'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff45'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48110,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff46'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff47'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff48'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff49'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff4a'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6196,
#   'SEX': 2,
#   'SGG': 48121,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff4b'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff4c'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff4d'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff4e'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff4f'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff50'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff51'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff52'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff53'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff54'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff55'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff56'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff57'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff58'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6616,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff59'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff5a'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff5b'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff5c'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff5d'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff5e'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff5f'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff60'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff61'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff62'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff63'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff64'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff65'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff66'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 6907,
#   'SEX': 1,
#   'SGG': 11680,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff67'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff68'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff69'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 6,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff6a'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 41570,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff6b'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff6c'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff6d'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff6e'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff6f'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff70'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff71'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff72'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff73'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff74'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8123,
#   'SEX': 1,
#   'SGG': 28260,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff75'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff76'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff77'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff78'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff79'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff7a'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff7b'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff7c'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff7d'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff7e'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff7f'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff80'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff81'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff82'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 8651,
#   'SEX': 1,
#   'SGG': 26290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff83'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff84'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff85'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff86'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff87'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff88'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff89'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff8a'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff8b'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff8c'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff8d'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff8e'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 42130,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff8f'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff90'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13228,
#   'SEX': 2,
#   'SGG': 11200,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff91'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff92'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff93'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff94'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff95'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff96'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff97'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff98'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff99'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11305,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff9a'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff9b'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff9c'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff9d'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff9e'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13456,
#   'SEX': 2,
#   'SGG': 11290,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ff9f'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa0'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa1'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa2'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa3'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa4'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa5'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa6'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa7'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 47750,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa8'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffa9'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffaa'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffab'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffac'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 13486,
#   'SEX': 1,
#   'SGG': 26350,
#   'GAIBJA_TYPE': 7,
#   'DSB_TYPE_CD': 5,
#   'SMPL_TYPE_CD': 1,
#   'DSB_SVRT_CD_V2': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffad'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffae'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffaf'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb0'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb1'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb2'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb3'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb4'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb5'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb6'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb7'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb8'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffb9'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffba'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 14250,
#   'SEX': 1,
#   'SGG': 48170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffbb'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffbc'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffbd'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffbe'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffbf'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc0'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc1'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 46790,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc2'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc3'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc4'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc5'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc6'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc7'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc8'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 14754,
#   'SEX': 2,
#   'SGG': 41463,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffc9'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffca'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffcb'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 42110,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffcc'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffcd'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffce'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffcf'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd0'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd1'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd2'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd3'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd4'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd5'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd6'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15383,
#   'SEX': 1,
#   'SGG': 11320,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd7'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd8'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffd9'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffda'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffdb'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffdc'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffdd'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffde'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffdf'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe0'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe1'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe2'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe3'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe4'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 15636,
#   'SEX': 1,
#   'SGG': 11590,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe5'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe6'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe7'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe8'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 17781,
#   'SEX': 2,
#   'SGG': 41135,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c55ffe9'),
#   'STD_YYYY': 2006,
# ...
#   'CTRB_Q10': 9,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56026f'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 82310,
#   'SEX': 2,
#   'SGG': 11740,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560270'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560271'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 7,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560272'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 9,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560273'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560274'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560275'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560276'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560277'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560278'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48160,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560279'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56027a'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56027b'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56027c'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56027d'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 83610,
#   'SEX': 1,
#   'SGG': 48125,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 10,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56027e'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56027f'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560280'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560281'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560282'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560283'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560284'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560285'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560286'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560287'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560288'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 46130,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560289'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56028a'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56028b'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84352,
#   'SEX': 1,
#   'SGG': 44270,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56028c'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56028d'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56028e'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56028f'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560290'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560291'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 1,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560292'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560293'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560294'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560295'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560296'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560297'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560298'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43113,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c560299'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 84893,
#   'SEX': 1,
#   'SGG': 43112,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56029a'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56029b'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56029c'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56029d'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56029e'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 28170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c56029f'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a0'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a1'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a2'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a3'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a4'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a5'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a6'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a7'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 85360,
#   'SEX': 2,
#   'SGG': 11170,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a8'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602a9'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602aa'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602ab'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602ac'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602ad'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602ae'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 4,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602af'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b0'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28245,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 6,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b1'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b2'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b3'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b4'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 6,
#   'CTRB_Q10': 5,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b5'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 87949,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b6'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b7'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b8'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602b9'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602ba'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602bb'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 1,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602bc'),
#   'STD_YYYY': 2008,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602bd'),
#   'STD_YYYY': 2009,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 3,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602be'),
#   'STD_YYYY': 2010,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 1,
#   'CTRB_Q10': 3,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602bf'),
#   'STD_YYYY': 2011,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c0'),
#   'STD_YYYY': 2012,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c1'),
#   'STD_YYYY': 2013,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c2'),
#   'STD_YYYY': 2014,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c3'),
#   'STD_YYYY': 2015,
#   'RN_INDI': 89343,
#   'SEX': 2,
#   'SGG': 28237,
#   'GAIBJA_TYPE': 5,
#   'CTRB_Q10': 2,
#   'G1E_OBJ_YN': 'Y',
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c4'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c5'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d311d91202dc332c5602c6'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 89809,
#   'SEX': 2,
#   'SGG': 30170,
#   'GAIBJA_TYPE': 2,
#   'CTRB_Q10': 8,
#   'SMPL_TYPE_CD': 1},
#  ...]

# %%
df_BNC = pd.DataFrame(list_BNC)

# %%
df_BNC
# Out:
#                             _id  STD_YYYY  RN_INDI  SEX    SGG  GAIBJA_TYPE  \
# 0      64d311d91202dc332c55fedf      2002     1433    1  29140            7
# 1      64d311d91202dc332c55fee0      2003     1433    1  29140            7
# 2      64d311d91202dc332c55fee1      2004     1433    1  29140            7
# 3      64d311d91202dc332c55fee2      2005     1433    1  29140            7
# 4      64d311d91202dc332c55fee3      2006     1433    1  29140            7
# ...                         ...       ...      ...  ...    ...          ...
# 13022  64d311da1202dc332c5631bd      2012  3000357    2  28237            6
# 13023  64d311da1202dc332c5631be      2013  3000357    2  28245            2
# 13024  64d311da1202dc332c5631bf      2014  3000357    2  28245            2
# 13025  64d311da1202dc332c5631c0      2015  3000357    2  28245            2
# 13026  64d311da1202dc332c5631c1      2015  3000758    1  41287            6
#
#        SMPL_TYPE_CD  CTRB_Q10 G1E_OBJ_YN  DSB_TYPE_CD  DSB_SVRT_CD_V2
# 0                 1       NaN        NaN          NaN             NaN
# 1                 1       NaN        NaN          NaN             NaN
# 2                 1       NaN        NaN          NaN             NaN
# 3                 1       NaN        NaN          NaN             NaN
# 4                 1       NaN        NaN          NaN             NaN
# ...             ...       ...        ...          ...             ...
# 13022             4       NaN        NaN          NaN             NaN
# 13023             4       6.0        NaN          NaN             NaN
# 13024             4       6.0        NaN          NaN             NaN
# 13025             4       7.0        NaN          NaN             NaN
# 13026             4       NaN        NaN          NaN             NaN
#
# [13027 rows x 11 columns]

# %%
df_BNC.to_csv('./NSC2_BNC_V2_1.csv')
