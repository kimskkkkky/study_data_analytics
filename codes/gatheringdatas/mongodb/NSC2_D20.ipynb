# %%
import pymongo as mg
import pandas as pd

# %%
client = mg.MongoClient(host= 'mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['NSC2_D20']

# %%
cursor = collection.find({})

# %%
list_NSC2 = list(cursor)

# %%
list_NSC2
# Out:
# [{'_id': ObjectId('64d313bb1202dc332c5631c3'),
#   'RN_INDI': 668008,
#   'RN_KEY': 2002030294303,
#   'RN_INST': 140010,
#   'MDCARE_STRT_DT': 20020325,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K051',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12480,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8980,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631c4'),
#   'RN_INDI': 440063,
#   'RN_KEY': 2002030797621,
#   'RN_INST': 139680,
#   'MDCARE_STRT_DT': 20020325,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11970,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8470,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631c5'),
#   'RN_INDI': 850654,
#   'RN_KEY': 2002030372244,
#   'RN_INST': 15041,
#   'MDCARE_STRT_DT': 20020311,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11970,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8470,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631c6'),
#   'RN_INDI': 783723,
#   'RN_KEY': 2002010004364,
#   'RN_INST': 108288,
#   'MDCARE_STRT_DT': 20020121,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11970,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8470,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631c7'),
#   'RN_INDI': 838106,
#   'RN_KEY': 2002010628708,
#   'RN_INST': 83960,
#   'MDCARE_STRT_DT': 20020105,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11970,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8470,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631c8'),
#   'RN_INDI': 231812,
#   'RN_KEY': 2002070694607,
#   'RN_INST': 78534,
#   'MDCARE_STRT_DT': 20020722,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631c9'),
#   'RN_INDI': 733272,
#   'RN_KEY': 2002070012884,
#   'RN_INST': 8735,
#   'MDCARE_STRT_DT': 20020730,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ca'),
#   'RN_INDI': 22071,
#   'RN_KEY': 2002090576976,
#   'RN_INST': 145021,
#   'MDCARE_STRT_DT': 20020930,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631cb'),
#   'RN_INDI': 806729,
#   'RN_KEY': 2002050194951,
#   'RN_INST': 66160,
#   'MDCARE_STRT_DT': 20020522,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K052',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631cc'),
#   'RN_INDI': 631006,
#   'RN_KEY': 2002070211847,
#   'RN_INST': 82431,
#   'MDCARE_STRT_DT': 20020703,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631cd'),
#   'RN_INDI': 73610,
#   'RN_KEY': 2002050568267,
#   'RN_INST': 48299,
#   'MDCARE_STRT_DT': 20020503,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K008',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ce'),
#   'RN_INDI': 55619,
#   'RN_KEY': 2002040672474,
#   'RN_INST': 135668,
#   'MDCARE_STRT_DT': 20020426,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631cf'),
#   'RN_INDI': 741694,
#   'RN_KEY': 2002090697142,
#   'RN_INST': 40733,
#   'MDCARE_STRT_DT': 20020926,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K052',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d0'),
#   'RN_INDI': 830143,
#   'RN_KEY': 2002080291958,
#   'RN_INST': 69946,
#   'MDCARE_STRT_DT': 20020802,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K045',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d1'),
#   'RN_INDI': 44863,
#   'RN_KEY': 2002070319389,
#   'RN_INST': 43171,
#   'MDCARE_STRT_DT': 20020725,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11640,
#   'EDC_SBA': 1500,
#   'EDC_INSUR_BRDN_AMT': 10140,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d2'),
#   'RN_INDI': 231812,
#   'RN_KEY': 2002080290291,
#   'RN_INST': 116376,
#   'MDCARE_STRT_DT': 20020805,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d3'),
#   'RN_INDI': 862062,
#   'RN_KEY': 2002060413586,
#   'RN_INST': 4176,
#   'MDCARE_STRT_DT': 20020612,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d4'),
#   'RN_INDI': 774839,
#   'RN_KEY': 2002040090446,
#   'RN_INST': 126375,
#   'MDCARE_STRT_DT': 20020411,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K121',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d5'),
#   'RN_INDI': 576619,
#   'RN_KEY': 2002070758957,
#   'RN_INST': 113377,
#   'MDCARE_STRT_DT': 20020702,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K121',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d6'),
#   'RN_INDI': 128961,
#   'RN_KEY': 2002080788909,
#   'RN_INST': 90381,
#   'MDCARE_STRT_DT': 20020827,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 56,
#   'SICK_SYM1': 'K121',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d7'),
#   'RN_INDI': 631006,
#   'RN_KEY': 2002050125678,
#   'RN_INST': 82431,
#   'MDCARE_STRT_DT': 20020523,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 56,
#   'SICK_SYM1': 'K121',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d8'),
#   'RN_INDI': 546675,
#   'RN_KEY': 2002050170034,
#   'RN_INST': 52696,
#   'MDCARE_STRT_DT': 20020501,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 56,
#   'SICK_SYM1': 'K121',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631d9'),
#   'RN_INDI': 186645,
#   'RN_KEY': 2002040476832,
#   'RN_INST': 16413,
#   'MDCARE_STRT_DT': 20020424,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631da'),
#   'RN_INDI': 184935,
#   'RN_KEY': 2002050017068,
#   'RN_INST': 95674,
#   'MDCARE_STRT_DT': 20020504,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 1,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8930,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5430,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631db'),
#   'RN_INDI': 184935,
#   'RN_KEY': 2002080743587,
#   'RN_INST': 97480,
#   'MDCARE_STRT_DT': 20020823,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631dc'),
#   'RN_INDI': 313232,
#   'RN_KEY': 2002070579542,
#   'RN_INST': 25592,
#   'MDCARE_STRT_DT': 20020706,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631dd'),
#   'RN_INDI': 565772,
#   'RN_KEY': 2002070234879,
#   'RN_INST': 99329,
#   'MDCARE_STRT_DT': 20020704,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631de'),
#   'RN_INDI': 13228,
#   'RN_KEY': 2002100612234,
#   'RN_INST': 125127,
#   'MDCARE_STRT_DT': 20021016,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631df'),
#   'RN_INDI': 783723,
#   'RN_KEY': 2002070803523,
#   'RN_INST': 102665,
#   'MDCARE_STRT_DT': 20020722,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e0'),
#   'RN_INDI': 646251,
#   'RN_KEY': 2002050695851,
#   'RN_INST': 138794,
#   'MDCARE_STRT_DT': 20020502,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e1'),
#   'RN_INDI': 323839,
#   'RN_KEY': 2002050223263,
#   'RN_INST': 98351,
#   'MDCARE_STRT_DT': 20020518,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K046',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7120,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3620,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e2'),
#   'RN_INDI': 1003337,
#   'RN_KEY': 2002010031186,
#   'RN_INST': 146561,
#   'MDCARE_STRT_DT': 20020128,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 57,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11980,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8480,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e3'),
#   'RN_INDI': 62782,
#   'RN_KEY': 2002010626455,
#   'RN_INST': 88155,
#   'MDCARE_STRT_DT': 20020125,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K052',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11980,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8480,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e4'),
#   'RN_INDI': 308173,
#   'RN_KEY': 2002030066613,
#   'RN_INST': 140676,
#   'MDCARE_STRT_DT': 20020327,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 16570,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 13070,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e5'),
#   'RN_INDI': 782784,
#   'RN_KEY': 2002010402901,
#   'RN_INST': 68080,
#   'MDCARE_STRT_DT': 20020131,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12520,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9020,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e6'),
#   'RN_INDI': 42659,
#   'RN_KEY': 2002020383269,
#   'RN_INST': 113734,
#   'MDCARE_STRT_DT': 20020214,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9200,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5700,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e7'),
#   'RN_INDI': 254163,
#   'RN_KEY': 2002010265371,
#   'RN_INST': 911,
#   'MDCARE_STRT_DT': 20020102,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K020',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9200,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5700,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e8'),
#   'RN_INDI': 758449,
#   'RN_KEY': 2002020377641,
#   'RN_INST': 125886,
#   'MDCARE_STRT_DT': 20020209,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9200,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5700,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631e9'),
#   'RN_INDI': 414780,
#   'RN_KEY': 2002080477078,
#   'RN_INST': 84300,
#   'MDCARE_STRT_DT': 20020822,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K050',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 1,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 15750,
#   'EDC_SBA': 4720,
#   'EDC_INSUR_BRDN_AMT': 11030,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ea'),
#   'RN_INDI': 594404,
#   'RN_KEY': 2002020601854,
#   'RN_INST': 142063,
#   'MDCARE_STRT_DT': 20020208,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K035',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7340,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3840,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631eb'),
#   'RN_INDI': 507438,
#   'RN_KEY': 2002020745606,
#   'RN_INST': 81028,
#   'MDCARE_STRT_DT': 20020209,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7340,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3840,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ec'),
#   'RN_INDI': 99170,
#   'RN_KEY': 2002020124655,
#   'RN_INST': 88058,
#   'MDCARE_STRT_DT': 20020225,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7340,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3840,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ed'),
#   'RN_INDI': 870877,
#   'RN_KEY': 2002030265599,
#   'RN_INST': 5801,
#   'MDCARE_STRT_DT': 20020311,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K088',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7340,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3840,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ee'),
#   'RN_INDI': 870877,
#   'RN_KEY': 2002010271072,
#   'RN_INST': 5801,
#   'MDCARE_STRT_DT': 20020129,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12960,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9460,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ef'),
#   'RN_INDI': 997203,
#   'RN_KEY': 2002040140849,
#   'RN_INST': 101241,
#   'MDCARE_STRT_DT': 20020412,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K020',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12600,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9100,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f0'),
#   'RN_INDI': 13228,
#   'RN_KEY': 2002010156634,
#   'RN_INST': 125127,
#   'MDCARE_STRT_DT': 20020102,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 51,
#   'SICK_SYM1': 'K047',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 6090,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 2590,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f1'),
#   'RN_INDI': 599309,
#   'RN_KEY': 2002060063217,
#   'RN_INST': 123328,
#   'MDCARE_STRT_DT': 20020607,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.25,
#   'ED_RC_TOT_AMT': 9230,
#   'EDC_SBA': 4610,
#   'EDC_INSUR_BRDN_AMT': 4620,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f2'),
#   'RN_INDI': 405681,
#   'RN_KEY': 2002010453738,
#   'RN_INST': 37558,
#   'MDCARE_STRT_DT': 20020123,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12620,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9120,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f3'),
#   'RN_INDI': 171812,
#   'RN_KEY': 2002070283831,
#   'RN_INST': 6663,
#   'MDCARE_STRT_DT': 20020723,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9810,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 6310,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f4'),
#   'RN_INDI': 415031,
#   'RN_KEY': 2002040731773,
#   'RN_INST': 92081,
#   'MDCARE_STRT_DT': 20020419,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9810,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 6310,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f5'),
#   'RN_INDI': 533519,
#   'RN_KEY': 2002050667928,
#   'RN_INST': 96205,
#   'MDCARE_STRT_DT': 20020528,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K045',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9810,
#   'EDC_SBA': 1500,
#   'EDC_INSUR_BRDN_AMT': 8310,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f6'),
#   'RN_INDI': 786621,
#   'RN_KEY': 2002070257865,
#   'RN_INST': 108453,
#   'MDCARE_STRT_DT': 20020716,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K050',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8920,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5420,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f7'),
#   'RN_INDI': 248794,
#   'RN_KEY': 2002040876778,
#   'RN_INST': 128247,
#   'MDCARE_STRT_DT': 20020410,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 21670,
#   'EDC_SBA': 6500,
#   'EDC_INSUR_BRDN_AMT': 15170,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f8'),
#   'RN_INDI': 658189,
#   'RN_KEY': 2002050406552,
#   'RN_INST': 14087,
#   'MDCARE_STRT_DT': 20020521,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 21670,
#   'EDC_SBA': 7000,
#   'EDC_INSUR_BRDN_AMT': 14670,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631f9'),
#   'RN_INDI': 235746,
#   'RN_KEY': 2002050792948,
#   'RN_INST': 127350,
#   'MDCARE_STRT_DT': 20020531,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K020',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 9420,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5920,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631fa'),
#   'RN_INDI': 214806,
#   'RN_KEY': 2002020025836,
#   'RN_INST': 15333,
#   'MDCARE_STRT_DT': 20020227,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 10100,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 6600,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631fb'),
#   'RN_INDI': 763784,
#   'RN_KEY': 2002010505798,
#   'RN_INST': 21192,
#   'MDCARE_STRT_DT': 20020103,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 1,
#   'EDC_ADD_RT': 0.25,
#   'ED_RC_TOT_AMT': 10850,
#   'EDC_SBA': 6510,
#   'EDC_INSUR_BRDN_AMT': 4340,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631fc'),
#   'RN_INDI': 262509,
#   'RN_KEY': 2002050343402,
#   'RN_INST': 113951,
#   'MDCARE_STRT_DT': 20020517,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K051',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7130,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3630,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631fd'),
#   'RN_INDI': 739343,
#   'RN_KEY': 2002040449921,
#   'RN_INST': 143860,
#   'MDCARE_STRT_DT': 20020415,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K009',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14310,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10810,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631fe'),
#   'RN_INDI': 652355,
#   'RN_KEY': 2002060643915,
#   'RN_INST': 40763,
#   'MDCARE_STRT_DT': 20020621,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14310,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10810,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c5631ff'),
#   'RN_INDI': 128961,
#   'RN_KEY': 2002050771911,
#   'RN_INST': 90381,
#   'MDCARE_STRT_DT': 20020521,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K000',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14310,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10810,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563200'),
#   'RN_INDI': 796080,
#   'RN_KEY': 2002070279657,
#   'RN_INST': 145400,
#   'MDCARE_STRT_DT': 20020702,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12110,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8610,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563201'),
#   'RN_INDI': 17781,
#   'RN_KEY': 2002070794042,
#   'RN_INST': 102200,
#   'MDCARE_STRT_DT': 20020718,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 19130,
#   'EDC_SBA': 5730,
#   'EDC_INSUR_BRDN_AMT': 13400,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563202'),
#   'RN_INDI': 283913,
#   'RN_KEY': 2002090052226,
#   'RN_INST': 83775,
#   'MDCARE_STRT_DT': 20020921,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K051',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 15310,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11810,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563203'),
#   'RN_INDI': 752588,
#   'RN_KEY': 2002060023303,
#   'RN_INST': 126827,
#   'MDCARE_STRT_DT': 20020626,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K050',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 15310,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11810,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563204'),
#   'RN_INDI': 325390,
#   'RN_KEY': 2002030944927,
#   'RN_INST': 50070,
#   'MDCARE_STRT_DT': 20020330,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14830,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11330,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563205'),
#   'RN_INDI': 629788,
#   'RN_KEY': 2002050885325,
#   'RN_INST': 56123,
#   'MDCARE_STRT_DT': 20020515,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12820,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9320,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563206'),
#   'RN_INDI': 426890,
#   'RN_KEY': 2002080298950,
#   'RN_INST': 103373,
#   'MDCARE_STRT_DT': 20020827,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14750,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11250,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563207'),
#   'RN_INDI': 87949,
#   'RN_KEY': 2002040717897,
#   'RN_INST': 18786,
#   'MDCARE_STRT_DT': 20020402,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14750,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11250,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563208'),
#   'RN_INDI': 783799,
#   'RN_KEY': 2002080374657,
#   'RN_INST': 67979,
#   'MDCARE_STRT_DT': 20020822,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 56,
#   'SICK_SYM1': 'K121',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14360,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10860,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563209'),
#   'RN_INDI': 85360,
#   'RN_KEY': 2002010537004,
#   'RN_INST': 65784,
#   'MDCARE_STRT_DT': 20020115,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K076',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 1,
#   'EDC_ADD_RT': 0.3,
#   'ED_RC_TOT_AMT': 13900,
#   'EDC_SBA': 9030,
#   'EDC_INSUR_BRDN_AMT': 4870,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56320a'),
#   'RN_INDI': 365179,
#   'RN_KEY': 2002050294582,
#   'RN_INST': 101241,
#   'MDCARE_STRT_DT': 20020502,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8610,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 5110,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56320b'),
#   'RN_INDI': 821649,
#   'RN_KEY': 2002060616885,
#   'RN_INST': 53109,
#   'MDCARE_STRT_DT': 20020601,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K045',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 20220,
#   'EDC_SBA': 6060,
#   'EDC_INSUR_BRDN_AMT': 14160,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56320c'),
#   'RN_INDI': 436198,
#   'RN_KEY': 2002040627086,
#   'RN_INST': 104864,
#   'MDCARE_STRT_DT': 20020408,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K122',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11900,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8400,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56320d'),
#   'RN_INDI': 400685,
#   'RN_KEY': 2002060462924,
#   'RN_INST': 104594,
#   'MDCARE_STRT_DT': 20020620,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K000',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 13110,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9610,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56320e'),
#   'RN_INDI': 829742,
#   'RN_KEY': 2002080556164,
#   'RN_INST': 83309,
#   'MDCARE_STRT_DT': 20020821,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 13110,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9610,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56320f'),
#   'RN_INDI': 546675,
#   'RN_KEY': 2002070815653,
#   'RN_INST': 52696,
#   'MDCARE_STRT_DT': 20020719,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'Z463',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 10230,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 6730,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563210'),
#   'RN_INDI': 69810,
#   'RN_KEY': 2002010070280,
#   'RN_INST': 134777,
#   'MDCARE_STRT_DT': 20020105,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K022',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 19700,
#   'EDC_SBA': 5910,
#   'EDC_INSUR_BRDN_AMT': 13790,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563211'),
#   'RN_INDI': 586351,
#   'RN_KEY': 2002060493555,
#   'RN_INST': 934,
#   'MDCARE_STRT_DT': 20020603,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 13350,
#   'EDC_SBA': 1500,
#   'EDC_INSUR_BRDN_AMT': 11850,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563212'),
#   'RN_INDI': 758751,
#   'RN_KEY': 2002040175134,
#   'RN_INST': 127057,
#   'MDCARE_STRT_DT': 20020408,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7070,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3570,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563213'),
#   'RN_INDI': 968275,
#   'RN_KEY': 2002060462901,
#   'RN_INST': 95112,
#   'MDCARE_STRT_DT': 20020607,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 7,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 17990,
#   'EDC_SBA': 7000,
#   'EDC_INSUR_BRDN_AMT': 10990,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563214'),
#   'RN_INDI': 774839,
#   'RN_KEY': 2002020744265,
#   'RN_INST': 126375,
#   'MDCARE_STRT_DT': 20020223,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 21260,
#   'EDC_SBA': 6370,
#   'EDC_INSUR_BRDN_AMT': 14890,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563215'),
#   'RN_INDI': 176697,
#   'RN_KEY': 2002070268073,
#   'RN_INST': 18922,
#   'MDCARE_STRT_DT': 20020712,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K031',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 20750,
#   'EDC_SBA': 6220,
#   'EDC_INSUR_BRDN_AMT': 14530,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563216'),
#   'RN_INDI': 694471,
#   'RN_KEY': 2002020226609,
#   'RN_INST': 18342,
#   'MDCARE_STRT_DT': 20020206,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K051',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 15770,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 12270,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563217'),
#   'RN_INDI': 393656,
#   'RN_KEY': 2002030053901,
#   'RN_INST': 81438,
#   'MDCARE_STRT_DT': 20020308,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 15770,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 12270,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563218'),
#   'RN_INDI': 802803,
#   'RN_KEY': 2002090271848,
#   'RN_INST': 42688,
#   'MDCARE_STRT_DT': 20020905,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7560,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 4060,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563219'),
#   'RN_INDI': 968275,
#   'RN_KEY': 2002040187335,
#   'RN_INST': 95112,
#   'MDCARE_STRT_DT': 20020430,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7560,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 4060,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56321a'),
#   'RN_INDI': 327665,
#   'RN_KEY': 2002040950720,
#   'RN_INST': 407,
#   'MDCARE_STRT_DT': 20020420,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14070,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10570,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56321b'),
#   'RN_INDI': 233697,
#   'RN_KEY': 2002010912550,
#   'RN_INST': 57448,
#   'MDCARE_STRT_DT': 20020125,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14740,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11240,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56321c'),
#   'RN_INDI': 362517,
#   'RN_KEY': 2002050104689,
#   'RN_INST': 101053,
#   'MDCARE_STRT_DT': 20020507,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 21790,
#   'EDC_SBA': 6530,
#   'EDC_INSUR_BRDN_AMT': 15260,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56321d'),
#   'RN_INDI': 802803,
#   'RN_KEY': 2002010222963,
#   'RN_INST': 70758,
#   'MDCARE_STRT_DT': 20020129,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 17550,
#   'EDC_SBA': 5260,
#   'EDC_INSUR_BRDN_AMT': 12290,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56321e'),
#   'RN_INDI': 217071,
#   'RN_KEY': 2002010632178,
#   'RN_INST': 132318,
#   'MDCARE_STRT_DT': 20020107,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 10560,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 7060,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56321f'),
#   'RN_INDI': 534381,
#   'RN_KEY': 2002020800243,
#   'RN_INST': 38722,
#   'MDCARE_STRT_DT': 20020221,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 18560,
#   'EDC_SBA': 5560,
#   'EDC_INSUR_BRDN_AMT': 13000,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563220'),
#   'RN_INDI': 151244,
#   'RN_KEY': 2002020326479,
#   'RN_INST': 104310,
#   'MDCARE_STRT_DT': 20020223,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7480,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3980,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563221'),
#   'RN_INDI': 176406,
#   'RN_KEY': 2002020512446,
#   'RN_INST': 140284,
#   'MDCARE_STRT_DT': 20020206,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7480,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 3980,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563222'),
#   'RN_INDI': 394016,
#   'RN_KEY': 2002050232066,
#   'RN_INST': 60933,
#   'MDCARE_STRT_DT': 20020531,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 13470,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9970,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563223'),
#   'RN_INDI': 391223,
#   'RN_KEY': 2002050449928,
#   'RN_INST': 1099,
#   'MDCARE_STRT_DT': 20020516,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 13100,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9600,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563224'),
#   'RN_INDI': 365179,
#   'RN_KEY': 2002040061703,
#   'RN_INST': 101241,
#   'MDCARE_STRT_DT': 20020429,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K006',
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11610,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8110,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563225'),
#   'RN_INDI': 941014,
#   'RN_KEY': 2002070847375,
#   'RN_INST': 15700,
#   'MDCARE_STRT_DT': 20020723,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K050',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 18030,
#   'EDC_SBA': 5400,
#   'EDC_INSUR_BRDN_AMT': 12630,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563226'),
#   'RN_INDI': 194269,
#   'RN_KEY': 2002040358558,
#   'RN_INST': 127769,
#   'MDCARE_STRT_DT': 20020409,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 8420,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 4920,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563227'),
#   'RN_INDI': 991645,
#   'RN_KEY': 2002020201123,
#   'RN_INST': 44956,
#   'MDCARE_STRT_DT': 20020218,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K036',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 11810,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8310,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563228'),
#   'RN_INDI': 1005080,
#   'RN_KEY': 2002020712183,
#   'RN_INST': 58537,
#   'MDCARE_STRT_DT': 20020216,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14770,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 11270,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c563229'),
#   'RN_INDI': 151244,
#   'RN_KEY': 2002030384040,
#   'RN_INST': 104310,
#   'MDCARE_STRT_DT': 20020302,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12690,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9190,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56322a'),
#   'RN_INDI': 312669,
#   'RN_KEY': 2002030531051,
#   'RN_INST': 81147,
#   'MDCARE_STRT_DT': 20020325,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 10540,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 7040,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56322b'),
#   'RN_INDI': 256571,
#   'RN_KEY': 2002020694126,
#   'RN_INST': 83715,
#   'MDCARE_STRT_DT': 20020209,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14490,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10990,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56322c'),
#   'RN_INDI': 936246,
#   'RN_KEY': 2002030082195,
#   'RN_INST': 125271,
#   'MDCARE_STRT_DT': 20020304,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K028',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 12060,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 8560,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56322d'),
#   'RN_INDI': 327665,
#   'RN_KEY': 2002060823070,
#   'RN_INST': 407,
#   'MDCARE_STRT_DT': 20020603,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 19170,
#   'EDC_SBA': 5750,
#   'EDC_INSUR_BRDN_AMT': 13420,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64d313bb1202dc332c56322e'),
#   'RN_INDI': 997976,
#   'RN_KEY': 2002020488048,
#   'RN_INST': 1334,
#   'MDCARE_STRT_DT': 20020227,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 13230,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 9730,
# ...
#   'RN_INDI': 573800,
#   'RN_KEY': 2003010178241,
#   'RN_INST': 65813,
#   'MDCARE_STRT_DT': 20030122,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 46860,
#   'EDC_SBA': 14050,
#   'EDC_INSUR_BRDN_AMT': 32810,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563589'),
#   'RN_INDI': 724104,
#   'RN_KEY': 2003010182472,
#   'RN_INST': 111753,
#   'MDCARE_STRT_DT': 20030122,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 42960,
#   'EDC_SBA': 12880,
#   'EDC_INSUR_BRDN_AMT': 30080,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56358a'),
#   'RN_INDI': 374166,
#   'RN_KEY': 2003120512476,
#   'RN_INST': 96826,
#   'MDCARE_STRT_DT': 20031223,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 58170,
#   'EDC_SBA': 17450,
#   'EDC_INSUR_BRDN_AMT': 40720,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56358b'),
#   'RN_INDI': 793097,
#   'RN_KEY': 2003050208992,
#   'RN_INST': 59764,
#   'MDCARE_STRT_DT': 20030516,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 67680,
#   'EDC_SBA': 20300,
#   'EDC_INSUR_BRDN_AMT': 47380,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56358c'),
#   'RN_INDI': 986521,
#   'RN_KEY': 2003010082644,
#   'RN_INST': 137502,
#   'MDCARE_STRT_DT': 20030117,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 50730,
#   'EDC_SBA': 15210,
#   'EDC_INSUR_BRDN_AMT': 35520,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56358d'),
#   'RN_INDI': 429577,
#   'RN_KEY': 2003040679014,
#   'RN_INST': 119639,
#   'MDCARE_STRT_DT': 20030416,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 3,
#   'VSHSP_DD_CNT': 3,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 61070,
#   'EDC_SBA': 18320,
#   'EDC_INSUR_BRDN_AMT': 42750,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56358e'),
#   'RN_INDI': 711345,
#   'RN_KEY': 2003090752018,
#   'RN_INST': 142163,
#   'MDCARE_STRT_DT': 20030929,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 30780,
#   'EDC_SBA': 9230,
#   'EDC_INSUR_BRDN_AMT': 21550,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56358f'),
#   'RN_INDI': 573784,
#   'RN_KEY': 2003100116572,
#   'RN_INST': 42737,
#   'MDCARE_STRT_DT': 20031016,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 43680,
#   'EDC_SBA': 13100,
#   'EDC_INSUR_BRDN_AMT': 30580,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563590'),
#   'RN_INDI': 267582,
#   'RN_KEY': 2003100539113,
#   'RN_INST': 56649,
#   'MDCARE_STRT_DT': 20031011,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 48140,
#   'EDC_SBA': 14440,
#   'EDC_INSUR_BRDN_AMT': 33700,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563591'),
#   'RN_INDI': 986085,
#   'RN_KEY': 2003070566633,
#   'RN_INST': 102808,
#   'MDCARE_STRT_DT': 20030725,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 32080,
#   'EDC_SBA': 9620,
#   'EDC_INSUR_BRDN_AMT': 22460,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563592'),
#   'RN_INDI': 314882,
#   'RN_KEY': 2003110283928,
#   'RN_INST': 137318,
#   'MDCARE_STRT_DT': 20031125,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 3,
#   'VSHSP_DD_CNT': 3,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 132580,
#   'EDC_SBA': 39770,
#   'EDC_INSUR_BRDN_AMT': 92810,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563593'),
#   'RN_INDI': 323550,
#   'RN_KEY': 2003110982576,
#   'RN_INST': 122452,
#   'MDCARE_STRT_DT': 20031115,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K020',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 65510,
#   'EDC_SBA': 19650,
#   'EDC_INSUR_BRDN_AMT': 45860,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563594'),
#   'RN_INDI': 535582,
#   'RN_KEY': 2003010470776,
#   'RN_INST': 54364,
#   'MDCARE_STRT_DT': 20030128,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 34040,
#   'EDC_SBA': 10210,
#   'EDC_INSUR_BRDN_AMT': 23830,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563595'),
#   'RN_INDI': 846679,
#   'RN_KEY': 2003040094123,
#   'RN_INST': 1405,
#   'MDCARE_STRT_DT': 20030419,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 3,
#   'VSHSP_DD_CNT': 3,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 64400,
#   'EDC_SBA': 19320,
#   'EDC_INSUR_BRDN_AMT': 45080,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563596'),
#   'RN_INDI': 414179,
#   'RN_KEY': 2003110443791,
#   'RN_INST': 83434,
#   'MDCARE_STRT_DT': 20031128,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 64240,
#   'EDC_SBA': 19270,
#   'EDC_INSUR_BRDN_AMT': 44970,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563597'),
#   'RN_INDI': 534192,
#   'RN_KEY': 2003010681887,
#   'RN_INST': 28745,
#   'MDCARE_STRT_DT': 20030125,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 42840,
#   'EDC_SBA': 12850,
#   'EDC_INSUR_BRDN_AMT': 29990,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563598'),
#   'RN_INDI': 446544,
#   'RN_KEY': 2003040944175,
#   'RN_INST': 75443,
#   'MDCARE_STRT_DT': 20030430,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 3,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 54750,
#   'EDC_SBA': 16420,
#   'EDC_INSUR_BRDN_AMT': 38330,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c563599'),
#   'RN_INDI': 732273,
#   'RN_KEY': 2003100468701,
#   'RN_INST': 104594,
#   'MDCARE_STRT_DT': 20031003,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K022',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 55060,
#   'EDC_SBA': 16510,
#   'EDC_INSUR_BRDN_AMT': 38550,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56359a'),
#   'RN_INDI': 618191,
#   'RN_KEY': 2003090651663,
#   'RN_INST': 28858,
#   'MDCARE_STRT_DT': 20030921,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K022',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 42220,
#   'EDC_SBA': 12660,
#   'EDC_INSUR_BRDN_AMT': 29560,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56359b'),
#   'RN_INDI': 815235,
#   'RN_KEY': 2003010484795,
#   'RN_INST': 134809,
#   'MDCARE_STRT_DT': 20030107,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 20910,
#   'EDC_SBA': 6270,
#   'EDC_INSUR_BRDN_AMT': 14640,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56359c'),
#   'RN_INDI': 841290,
#   'RN_KEY': 2003060860329,
#   'RN_INST': 98069,
#   'MDCARE_STRT_DT': 20030605,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K083',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 26990,
#   'EDC_SBA': 8090,
#   'EDC_INSUR_BRDN_AMT': 18900,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56359d'),
#   'RN_INDI': 273079,
#   'RN_KEY': 2003100467556,
#   'RN_INST': 75151,
#   'MDCARE_STRT_DT': 20031015,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 27920,
#   'EDC_SBA': 8370,
#   'EDC_INSUR_BRDN_AMT': 19550,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56359e'),
#   'RN_INDI': 267631,
#   'RN_KEY': 2003100339973,
#   'RN_INST': 60989,
#   'MDCARE_STRT_DT': 20031011,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K011',
#   'SICK_SYM2': 'K051',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 18080,
#   'EDC_SBA': 7000,
#   'EDC_INSUR_BRDN_AMT': 11080,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c56359f'),
#   'RN_INDI': 256571,
#   'RN_KEY': 2003090105692,
#   'RN_INST': 83715,
#   'MDCARE_STRT_DT': 20030905,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 53,
#   'SICK_SYM1': 'K006',
#   'SICK_SYM2': 'K021',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 17480,
#   'EDC_SBA': 5240,
#   'EDC_INSUR_BRDN_AMT': 12240,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a0'),
#   'RN_INDI': 96574,
#   'RN_KEY': 2003030393714,
#   'RN_INST': 4956,
#   'MDCARE_STRT_DT': 20030303,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K040',
#   'SICK_SYM2': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14420,
#   'EDC_SBA': 3500,
#   'EDC_INSUR_BRDN_AMT': 10920,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a1'),
#   'RN_INDI': 577109,
#   'RN_KEY': 2003120371232,
#   'RN_INST': 125313,
#   'MDCARE_STRT_DT': 20031203,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K053',
#   'SICK_SYM2': 'K089',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 1,
#   'EDC_ADD_RT': 0.25,
#   'ED_RC_TOT_AMT': 15610,
#   'EDC_SBA': 7800,
#   'EDC_INSUR_BRDN_AMT': 7810,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a2'),
#   'RN_INDI': 449947,
#   'RN_KEY': 2003050095472,
#   'RN_INST': 68901,
#   'MDCARE_STRT_DT': 20030528,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K044',
#   'SICK_SYM2': 'K046',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 18490,
#   'EDC_SBA': 5540,
#   'EDC_INSUR_BRDN_AMT': 12950,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a3'),
#   'RN_INDI': 414780,
#   'RN_KEY': 2003120857414,
#   'RN_INST': 6361,
#   'MDCARE_STRT_DT': 20031217,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K050',
#   'SICK_SYM2': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 19680,
#   'EDC_SBA': 5900,
#   'EDC_INSUR_BRDN_AMT': 13780,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a4'),
#   'RN_INDI': 267631,
#   'RN_KEY': 2003100347693,
#   'RN_INST': 97955,
#   'MDCARE_STRT_DT': 20031013,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K052',
#   'SICK_SYM2': 'K035',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 14980,
#   'EDC_SBA': 7000,
#   'EDC_INSUR_BRDN_AMT': 7980,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a5'),
#   'RN_INDI': 126693,
#   'RN_KEY': 2003110546429,
#   'RN_INST': 2529,
#   'MDCARE_STRT_DT': 20031121,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K051',
#   'SICK_SYM2': 'K056',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 18560,
#   'EDC_SBA': 5560,
#   'EDC_INSUR_BRDN_AMT': 13000,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a6'),
#   'RN_INDI': 78500,
#   'RN_KEY': 2003120883640,
#   'RN_INST': 110972,
#   'MDCARE_STRT_DT': 20031213,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K083',
#   'SICK_SYM2': 'K040',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 9,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 22290,
#   'EDC_SBA': 6680,
#   'EDC_INSUR_BRDN_AMT': 15610,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a7'),
#   'RN_INDI': 840698,
#   'RN_KEY': 2003090986188,
#   'RN_INST': 38499,
#   'MDCARE_STRT_DT': 20030915,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K02',
#   'SICK_SYM2': 'K006',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.2,
#   'ED_RC_TOT_AMT': 15690,
#   'EDC_SBA': 6270,
#   'EDC_INSUR_BRDN_AMT': 9420,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a8'),
#   'RN_INDI': 708939,
#   'RN_KEY': 2003080018446,
#   'RN_INST': 12807,
#   'MDCARE_STRT_DT': 20030808,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 50,
#   'SICK_SYM1': 'K011',
#   'SICK_SYM2': 'K053',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.2,
#   'ED_RC_TOT_AMT': 15690,
#   'EDC_SBA': 6270,
#   'EDC_INSUR_BRDN_AMT': 9420,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635a9'),
#   'RN_INDI': 449947,
#   'RN_KEY': 2003030947755,
#   'RN_INST': 68901,
#   'MDCARE_STRT_DT': 20030305,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 55,
#   'SICK_SYM1': 'K021',
#   'SICK_SYM2': 'K044',
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 0,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 22470,
#   'EDC_SBA': 7000,
#   'EDC_INSUR_BRDN_AMT': 15470,
#   'STD_YYYY': 2003},
#  {'_id': ObjectId('64d313bb1202dc332c5635aa'),
#   'RN_INDI': 847505,
#   'RN_KEY': 2003090842288,
#   'RN_INST': 41612,
#   'MDCARE_STRT_DT': 20030902,
#   'FORM_CD': 5,
#   'MCARE_SUBJ_CD': 54,
#   'SICK_SYM1': 'K050',
#   'SICK_SYM2': 'K011',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 4,
#   'VSHSP_DD_CNT': 4,
#   'TOT_PRSC_DD_CNT': 2,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 32780,
#   'EDC_SBA': 14000,
#   'EDC_INSUR_BRDN_AMT': 18780,
#   'STD_YYYY': 2003},
#  ...]

# %%
df_NSC2 = pd.DataFrame(list_NSC2)

# %%
df_NSC2
# Out:
#                             _id  RN_INDI         RN_KEY  RN_INST  \
# 0      64d313bb1202dc332c5631c3   668008  2002030294303   140010
# 1      64d313bb1202dc332c5631c4   440063  2002030797621   139680
# 2      64d313bb1202dc332c5631c5   850654  2002030372244    15041
# 3      64d313bb1202dc332c5631c6   783723  2002010004364   108288
# 4      64d313bb1202dc332c5631c7   838106  2002010628708    83960
# ...                         ...      ...            ...      ...
# 12525  64d313bc1202dc332c5662b0   312513  2015060094233   118846
# 12526  64d313bc1202dc332c5662b1   533519  2015042356807     7949
# 12527  64d313bc1202dc332c5662b2   423793  2015020324868    47288
# 12528  64d313bc1202dc332c5662b3   398604  2015010120760   116017
# 12529  64d313bc1202dc332c5662b4   398604  2015020991563   116017
#
#        MDCARE_STRT_DT  FORM_CD  MCARE_SUBJ_CD SICK_SYM1 OFIJ_TYPE  OPRTN_YN  \
# 0            20020325        5             54      K051         0         0
# 1            20020325        5             53      K006         0         9
# 2            20020311        5             53      K006         0         9
# 3            20020121        5             55      K006       NaN         9
# 4            20020105        5             50      K006       NaN         9
# ...               ...      ...            ...       ...       ...       ...
# 12525        20150627        5             55     K0300         0         0
# 12526        20150407        5             50     K0765         0         0
# 12527        20150221        5             55     K0766         0         0
# 12528        20150129        5             51      K081         0         9
# 12529        20150211        5             51      K081         0         0
#
#        ...  MCARE_RSLT_TYPE  EDC_ADD_RT  ED_RC_TOT_AMT  EDC_SBA  \
# 0      ...              5.0        0.15          12480     3500
# 1      ...              5.0        0.15          11970     3500
# 2      ...              5.0        0.15          11970     3500
# 3      ...              5.0        0.15          11970     3500
# 4      ...              5.0        0.15          11970     3500
# ...    ...              ...         ...            ...      ...
# 12525  ...              1.0        0.20          91460    36500
# 12526  ...              1.0        0.15          86030    25800
# 12527  ...              1.0        0.15          80490    23600
# 12528  ...              1.0        0.15         488170   244000
# 12529  ...              1.0        0.15         511600   255800
#
#        EDC_INSUR_BRDN_AMT  STD_YYYY  SICK_SYM2  HSPTZ_PATH_TYPE  \
# 0                    8980      2002        NaN              NaN
# 1                    8470      2002        NaN              NaN
# 2                    8470      2002        NaN              NaN
# 3                    8470      2002        NaN              NaN
# 4                    8470      2002        NaN              NaN
# ...                   ...       ...        ...              ...
# 12525               54960      2015        NaN              NaN
# 12526               60230      2015        NaN              NaN
# 12527               56890      2015        NaN              NaN
# 12528              244170      2015        NaN              NaN
# 12529              255800      2015        NaN              NaN
#
#        SPCF_SYM_TYPE FST_HSPTZ_DT
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ...              ...          ...
# 12525            NaN          NaN
# 12526            NaN          NaN
# 12527            NaN          NaN
# 12528            NaN          NaN
# 12529            NaN          NaN
#
# [12530 rows x 23 columns]

# %%
df_NSC2.to_csv('./NSC2_D20.csv')
